# %% [markdown]
# # Selecting samples of 10k articles from CC_News with 5 diversity metrics:
# 1. [Setup / Removing non-English articles from the dataset](#setup)
# 2. [Random](#random)
# 3. [Mean TFIDF](#meantfidf)
# 4. [Jaccard similarity](#jaccard) -- ERROR: jaccard similarity not successfully scaled to CC_News dataset
# 5. [Trigram language model entropy](#3entropy)
# 6. [Measures of embedding diversity:](#embedding)
#     1. [Outlier](#outlier)
#     2. [Word Embedding Diversity](#wed)
# <br>
# *all metrics were computed, and models subsequently trained, using CPU on a macbook with M1 pro chip

# %%
__author__ = "Jon Ball"
__version__ = "CS224U, Stanford, Spring 2022"

# %% [markdown]
# Setup modules:

# %%
from datasets import load_dataset
from tqdm import tqdm
import numpy as np
import utils
import json
import time
import os

# %% [markdown]
# For reproducibility:

# %%
utils.fix_random_seeds()

# %% [markdown]
# Data:

# %%
ccn = load_dataset("cc_news", split="train")["text"]
# Out:
# Reusing dataset cc_news (/Users/jball/.cache/huggingface/datasets/cc_news/plain_text/1.0.0/ae469e556251e6e7e20a789f93803c7de19d0c4311b6854ab072fecb4e401bd6)

# %%
print(f"Number of articles: {len(ccn)}\n")
print(ccn[0])
# Out:
# Number of articles: 708241
#
# There's a surprising twist to Regina Willoughby's last season with Columbia City Ballet: It's also her 18-year-old daughter Melina's first season with the company. Regina, 40, will retire from the stage in March, just as her daughter starts her own career as a trainee. But for this one season, they're sharing the stage together.
# Performing Side-By-Side In The Nutcracker
# Regina and Melina are not only dancing in the same Nutcracker this month, they're onstage at the same time: Regina is doing Snow Queen, while Melina is in the snow corps, and they're both in the Arabian divertissement. "It's very surreal to be dancing it together," says Regina. "I don't know that I ever thought Melina would take ballet this far."
# Left: Regina and Melina with another company member post-snow scene in 2003. Right: The pair post-snow scene in 2017 (in the same theater)
# Keep reading at dancemagazine.com.

# %% [markdown]
# ### Check that the CC_News articles are actually in English using <a href="https://github.com/google/cld3">gcld3</a>: <a id="setup"></a>

# %%
import gcld3

# %%
classifier = gcld3.NNetLanguageIdentifier(min_num_bytes=0, max_num_bytes=100000)

# %%
for idx, article in enumerate(ccn):
    result = classifier.FindLanguage(text=article)
    if result.language != "en":
        print(idx, "\n", article)
        break
# Out:
# 89
#  ০ = 0, ১ = 1, ২ = 2, ৩ = 3, ৪ = 4, ৫ = 5, ৬ = 6, ৭ = 7, ৮ = 8, ৯ = 9
# ্ = See example (Hasant/Viram) ় = * (Nukta) ʼ = ' (Urdhacomma) ঽ = & (Avagrah) ৺ = ~ (Isshar) ৹ = a~ (Bengali ana sign) ৲ = Rs~ (Bengali Rupee sign) ৳ = T~ (Taka sign) । = | (Devanagari danda) ॥ = || (Devanagari double danda) ₹ = Rs (Indian Rupee sign) 卐 = +~ (Swastika sign) Zero Width Joiner = ^ Zero Width Non Joiner = ^^
# These symbols will type Bengali characters first but if "~" will be followed, it will remove previously typed Bengali character and then type the symbol.
# Symbols & ~ * : ^ | ' have special meaning. You can type this way & = &~ ~ = ~~ * = *~ : = :~ ^ = ^~ | = |~ ' = '~
# The English symbols [ ] { } ( ) < > - + / = ; . , " ? ! % \ _ $ @ # translate into the same symbols.
# Example নমস্কার can be written by typing "namaskaar"
# As per Rule # 3, ligature will be rendered. ZWJ and ZWNJ characters are used to produce alternate rendering of ligature.
# A consonant followed by ZWJ character will produce half-formed consonant character.
# Example
# প্রশ্ন = prashn
# প্রশ্‍ন = prash^n
# A consonant followed by ZWNJ character will produce dead consonant character.
# Example
# প্রশ্ন = prashn
# প্রশ্‌ন = prash^^n
# If two english characters are making one Bengali Vowel (i.e. ai, au), then
# ZWJ character is used to separate them into two different vowels. It will not
# add ZWJ character but only considered as the separator between two
# vowels.

# %% [markdown]
# #### Use gcld3 to filter out articles like the above which are not fully English and likely to be included in each sample:

# %%
disinclusion_index = []
for idx, article in enumerate(tqdm(ccn)):
    result = classifier.FindLanguage(text=article)
    if result.language != "en":
        disinclusion_index.append(idx)
# Out:
# 100%|█████████████████████████████████| 708241/708241 [06:19<00:00, 1867.32it/s]

# %%
# %%time

cc_news = [
    article for idx, article in enumerate(ccn) if idx not in disinclusion_index
]
# Out:
# CPU times: user 21 s, sys: 33.1 ms, total: 21.1 s
# Wall time: 21.1 s

# %%
print(f"Number of clean articles: {len(cc_news)}")
# Out:
# Number of clean articles: 703532

# %%
with open(os.path.join("data", "cc_news.json"), "w") as outfile:
    json.dump(cc_news, outfile)

# %% [markdown]
# ## Mean-TFIDF (variation on Baeza-Yates et al. 1999) <a id="meanidf"></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from operator import itemgetter
import numpy as np
import json
import time
import os

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
tfidf_vec = TfidfVectorizer()

# %%
# %time tfidf_matrix = tfidf_vec.fit_transform(cc_news)
# Out:
# CPU times: user 1min 36s, sys: 2.57 s, total: 1min 39s
# Wall time: 1min 39s

# %%
def mean_idf(doc_idx, tfidf_matrix=tfidf_matrix, tfidf_vectorizer=tfidf_vec):
    feature_index = tfidf_matrix[doc_idx,:].nonzero()[1]
    word_idf_scores = tfidf_vectorizer.idf_[feature_index]
    return np.mean(word_idf_scores)

# %%
# %time cc_idf = [mean_idf(doc_idx) for doc_idx in range(len(cc_news))]
# Out:
# CPU times: user 19min 37s, sys: 5min 57s, total: 25min 34s
# Wall time: 25min 35s

# %%
print(f"""Max IDF: {max(cc_idf)}
Min IDF: {min(cc_idf)}
Mean: {np.mean(cc_idf)}
Std Dev: {np.std(cc_idf)}""")
# Out:
# Max IDF: 12.365534427447304
# Min IDF: 2.2256180368294363
# Mean: 4.42180964113847
# Std Dev: 0.5235009566338252

# %%
idf_indexed = list(enumerate(cc_idf))
idf_indexed10k = sorted(idf_indexed, key=itemgetter(1))[-10000:] #indices and top 10,000 Mean IDF scores
idf_indices10k = [tup[0] for tup in idf_indexed10k]
idf_scores10k = [tup[1] for tup in idf_indexed10k]

# %%
print(f"""Max IDF in subsample: {max(idf_scores10k)}
Min IDF in subsample: {min(idf_scores10k)}
Mean: {np.mean(idf_scores10k)}
Std Dev: {np.std(idf_scores10k)}""")
# Out:
# Max IDF in subsample: 12.365534427447304
# Min IDF in subsample: 5.776707236449172
# Mean: 6.319554792407199
# Std Dev: 0.5852270273612017

# %%
# %%time

cc_idf10k = [
    article for idx, article in enumerate(cc_news) if idx in idf_indices10k
]
# Out:
# CPU times: user 57 s, sys: 544 ms, total: 57.5 s
# Wall time: 57.5 s

# %%
with open(os.path.join("data", "cc_idf10k.json"), "w") as outfile:
    json.dump(cc_idf10k, outfile)

# %% [markdown]
# ## Jaccard distance <a id="jaccard"></a>

# %%
from tokenizers import BertWordPieceTokenizer
from operator import itemgetter
from tqdm import tqdm

import multiprocess as mp
import numpy as np
import time
import json
import os

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
tokenizer = BertWordPieceTokenizer(os.path.join("bert-base-uncased-vocab", "vocab.txt"))

# %%
cc_ids = tuple(
    [
        (article_idx, set(tokenizer.encode(cc_news[article_idx]).ids[:512]))\
        for article_idx in tqdm(range(len(cc_news)))
    ]
)
# Out:
# 100%|█████████████████████████████████| 703532/703532 [09:11<00:00, 1275.09it/s]

# %%
del cc_news, tokenizer, BertWordPieceTokenizer

# %%
def mean_jaccard_dist(article_idx, token_set):
    
    jdistances = [
        1.0 - len(token_set.intersection(ref_tuple[1])) / len(token_set.union(ref_tuple[1])) \
        for ref_tuple in cc_ids if article_idx != ref_tuple[0]
    ]
    
    return (article_idx, np.mean(jdistances))

# %%
Manually updated

# %%
# %%time

if __name__ == "__main__":
    
    with mp.Pool(8) as pool:
        cc_jaccard = pool.starmap(mean_jaccard_dist, cc_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:4, in <module>
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/multiprocess/pool.py:372, in Pool.starmap(self, func, iterable, chunksize)
#     366 def starmap(self, func, iterable, chunksize=None):
#     367     '''
#     368     Like `map()` method but the elements of the `iterable` are expected to
#     369     be iterables as well and will be unpacked as arguments. Hence
#     370     `func` and (a, b) becomes func(a, b).
#     371     '''
# --> 372     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/multiprocess/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/multiprocess/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Trigram language model entropy <a id="3entropy"></a>

# %%
from tokenizers import BertWordPieceTokenizer
from nltk.lm.preprocessing import pad_both_ends, flatten
from nltk.util import ngrams
from nltk.lm import MLE
from operator import itemgetter
from tqdm import tqdm
import numpy as np
import time
import json
import os

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
tokenizer = BertWordPieceTokenizer(os.path.join("bert-base-uncased-vocab", "vocab.txt"))

# %%
cc_toks = [
    tokenizer.encode(cc_news[article_idx]).tokens[:512] for article_idx in tqdm(range(len(cc_news)))
]
# Out:
# 100%|█████████████████████████████████| 703532/703532 [10:15<00:00, 1143.80it/s]

# %%
# %%time

cc_padded = [
    list(pad_both_ends(article_toks, n=3)) for article_toks in cc_toks
]
# Out:
# CPU times: user 10.3 s, sys: 57.3 s, total: 1min 7s
# Wall time: 1min 45s

# %%
cc_vocab = list(flatten(cc_padded))
print(len(cc_vocab))
# Out:
# 239677179

# %%
# %%time

cc_grams = [
    list(ngrams(article_padded, n=3)) for article_padded in cc_padded
]
# Out:
# CPU times: user 26.6 s, sys: 2min 19s, total: 2min 46s
# Wall time: 5min 59s

# %%
trigram_model = MLE(3)

# %%
# %time trigram_model.fit(cc_grams, cc_vocab)
# Out:
# CPU times: user 16min 42s, sys: 19min, total: 35min 43s
# Wall time: 1h 32s

# %%
cc_entropy = [
    trigram_model.entropy(cc_grams[article_idx]) for article_idx in tqdm(range(len(cc_grams)))
]
# Out:
# 100%|██████████████████████████████████| 703532/703532 [56:06<00:00, 208.96it/s]

# %%
print(f"""Max entropy: {max(cc_entropy)}
Min entropy: {min(cc_entropy)}
Mean: {np.mean(cc_entropy)}
Std Dev: {np.std(cc_entropy)}""")
# Out:
# Max entropy: 6.441736870435621
# Min entropy: 0.6607880940607269
# Mean: 4.531580789229363
# Std Dev: 0.9035417963006608

# %%
entropy_indexed = list(enumerate(cc_entropy))
entropy_indexed10k = sorted(entropy_indexed, key=itemgetter(1))[-10000:]
entropy_indices10k = [tup[0] for tup in entropy_indexed10k]
entropy_scores10k = [tup[1] for tup in entropy_indexed10k]

# %%
print(f"""Max entropy in subsample: {max(entropy_scores10k)}
Min entropy in subsample: {min(entropy_scores10k)}
Mean: {np.mean(entropy_scores10k)}
Std Dev: {np.std(entropy_scores10k)}""")
# Out:
# Max entropy in subsample: 6.441736870435621
# Min entropy in subsample: 5.589578462962402
# Mean: 5.680277063155953
# Std Dev: 0.08761192165393417

# %%
# %%time

cc_entropy10k = [
    article for idx, article in enumerate(cc_news) if idx in entropy_indices10k
]
# Out:
# CPU times: user 57.7 s, sys: 2.08 s, total: 59.8 s
# Wall time: 1min 4s

# %%
with open(os.path.join("data", "cc_entropy10k.json"), "w") as outfile:
    json.dump(cc_entropy10k, outfile)

# %%
with open(os.path.join("data", "cc_entropy10k.txt"), "w") as outfile:
    for article in cc_entropy10k:
        outfile.write(article)

# %% [markdown]
# ## Get embeddings <a id="embedding"></a>

# %%
import torch
import torch.nn as nn
from transformers import BertTokenizer, BertModel
from tqdm import tqdm
import numpy as np
import json
import time
import os

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# %%time
#using BertTokenizer rather than BertTokenizerFast to avoid forking parallelism issue with for-loop below
tokenized_inputs = [
    tokenizer(cc_news[doc_idx], truncation=True, max_length=512, padding="max_length", return_tensors="pt")\
    for doc_idx in range(len(cc_news))
]
# Out:
# CPU times: user 50min 53s, sys: 15 s, total: 51min 8s
# Wall time: 51min 9s

# %%
del cc_news

# %% [markdown]
# First pass (interrupted due to power outage):

# %%
def get_mean_pooled_array(article_idx, tokenized_inputs=tokenized_inputs):
    
    input_ = tokenized_inputs[article_idx]
    
    output_ = model(**input_, output_hidden_states=True)
    
    out_tensor = torch.mean(output_.last_hidden_state, axis=1)
    
    return out_tensor.detach().numpy()

# %%
# %%time

for article_idx in tqdm(range(len(tokenized_inputs))):
    
    arr = get_mean_pooled_array(article_idx)
    filename = "cc" + str(article_idx) + ".npy"
    np.save(os.path.join("data", "cc_arrays", filename), arr)
# Out:
#  50%|██████████████▌              | 352567/703532 [76:22:02<76:01:12,  1.28it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3, in <module>
#
# Input In [6], in get_mean_pooled_array(doc_idx, tokenized_inputs)
#       1 def get_mean_pooled_array(doc_idx, tokenized_inputs=tokenized_inputs):
#       3     input_ = tokenized_inputs[doc_idx]
# ----> 5     output_ = model(**input_, output_hidden_states=True)
#       7     out_tensor = torch.mean(output_.last_hidden_state, axis=1)
#       9     return out_tensor.detach().numpy()
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1017, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1008 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1010 embedding_output = self.embeddings(
#    1011     input_ids=input_ids,
#    1012     position_ids=position_ids,
#    (...)
#    1015     past_key_values_length=past_key_values_length,
#    1016 )
# -> 1017 encoder_outputs = self.encoder(
#    1018     embedding_output,
#    1019     attention_mask=extended_attention_mask,
#    1020     head_mask=head_mask,
#    1021     encoder_hidden_states=encoder_hidden_states,
#    1022     encoder_attention_mask=encoder_extended_attention_mask,
#    1023     past_key_values=past_key_values,
#    1024     use_cache=use_cache,
#    1025     output_attentions=output_attentions,
#    1026     output_hidden_states=output_hidden_states,
#    1027     return_dict=return_dict,
#    1028 )
#    1029 sequence_output = encoder_outputs[0]
#    1030 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:606, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     597     layer_outputs = torch.utils.checkpoint.checkpoint(
#     598         create_custom_forward(layer_module),
#     599         hidden_states,
#    (...)
#     603         encoder_attention_mask,
#     604     )
#     605 else:
# --> 606     layer_outputs = layer_module(
#     607         hidden_states,
#     608         attention_mask,
#     609         layer_head_mask,
#     610         encoder_hidden_states,
#     611         encoder_attention_mask,
#     612         past_key_value,
#     613         output_attentions,
#     614     )
#     616 hidden_states = layer_outputs[0]
#     617 if use_cache:
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:493, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     481 def forward(
#     482     self,
#     483     hidden_states: torch.Tensor,
#    (...)
#     490 ) -> Tuple[torch.Tensor]:
#     491     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     492     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 493     self_attention_outputs = self.attention(
#     494         hidden_states,
#     495         attention_mask,
#     496         head_mask,
#     497         output_attentions=output_attentions,
#     498         past_key_value=self_attn_past_key_value,
#     499     )
#     500     attention_output = self_attention_outputs[0]
#     502     # if decoder, the last output is tuple of self-attn cache
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:432, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     413 def forward(
#     414     self,
#     415     hidden_states: torch.Tensor,
#    (...)
#     421     output_attentions: Optional[bool] = False,
#     422 ) -> Tuple[torch.Tensor]:
#     423     self_outputs = self.self(
#     424         hidden_states,
#     425         attention_mask,
#    (...)
#     430         output_attentions,
#     431     )
# --> 432     attention_output = self.output(self_outputs[0], hidden_states)
#     433     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     434     return outputs
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:382, in BertSelfOutput.forward(self, hidden_states, input_tensor)
#     381 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 382     hidden_states = self.dense(hidden_states)
#     383     hidden_states = self.dropout(hidden_states)
#     384     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/anaconda3/envs/nlu/lib/python3.9/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# Second pass:

# %%
def get_mean_pooled_array(article_toks, model=model):
    
    output_ = model(**article_toks, output_hidden_states=True)
    
    out_tensor = torch.mean(output_.last_hidden_state, axis=1)
    
    return out_tensor.detach().numpy()

# %%
# %%time

for new_idx, article_toks in tqdm(enumerate(tokenized_inputs[352567:])):
    
    arr = get_mean_pooled_array(article_toks)
    filename = "cc" + str(new_idx + 352567) + ".npy"
    np.save(os.path.join("data", "cc_arrays", filename), arr)
# Out:
# 350965it [85:28:24,  1.14it/s]
# CPU times: user 26d 4min 32s, sys: 4d 6h 18min 12s, total: 30d 6h 22min 44s
# Wall time: 3d 13h 28min 24s

# %% [markdown]
# ## Euclidean distance from mean corpus vector (Stasaski et al., 2020; Larson et al., 2019)

# %%
from scipy.spatial.distance import euclidean
from operator import itemgetter
from tqdm import tqdm
import numpy as np
import json
import time
import os

# %%
arr_path = os.path.join("data", "cc_arrays")

# %%
for roots, dirs, files in os.walk(arr_path):
    
    print(len(files))

    indices = [
        int(filename[2:-4]) for filename in files
    ]
    
    filepaths = [
        os.path.join(arr_path, filename) for filename in files
    ]
    
    idx2path = sorted(
        list(zip(indices, filepaths)),
        key = itemgetter(0)
    )
    
    print(idx2path[0])
# Out:
# 703532
# (0, 'data/cc_arrays/cc0.npy')

# %%
cc_array = np.zeros((len(idx2path), 768))

for idx, filepath in tqdm(idx2path):
    
    arr = np.load(filepath)
    cc_array[idx] = arr
        
print(cc_array.shape)
# Out:
# 100%|█████████████████████████████████| 703532/703532 [01:44<00:00, 6734.86it/s]
# (703532, 768)

# %%
mean_arr = np.mean(cc_array, axis=0)

# %%
cc_eudist = []

for idx in tqdm(range(cc_array.shape[0])):
    eudist = euclidean(cc_array[idx], mean_arr)
    cc_eudist.append(eudist)
# Out:
# 100%|███████████████████████████████| 703532/703532 [00:02<00:00, 288114.68it/s]

# %%
print(f"""Max cosine distance from corpus mean: {max(cc_eudist)}
Min: {min(cc_eudist)}
Mean: {np.mean(cc_eudist)}
Std Dev: {np.std(cc_eudist)}""")
# Out:
# Max cosine distance from corpus mean: 13.397324553882964
# Min: 1.960511518807967
# Mean: 4.003239536662265
# Std Dev: 0.8837525446080264

# %%
eudist_indexed = list(enumerate(cc_eudist))
eudist_indexed10k = sorted(eudist_indexed, key=itemgetter(1))[-10000:]
eudist_indices10k = [tup[0] for tup in eudist_indexed10k]
eudist_scores10k = [tup[1] for tup in eudist_indexed10k]

# %%
print(f"""Max euclidean distance in subsample: {max(eudist_scores10k)}
Min: {min(eudist_scores10k)}
Mean: {np.mean(eudist_scores10k)}
Std Dev: {np.std(eudist_scores10k)}""")
# Out:
# Max euclidean distance in subsample: 13.397324553882964
# Min: 6.509962991455852
# Mean: 6.921735291458649
# Std Dev: 0.5148770026302417

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
# %%time

cc_eudist10k = [
    article for idx, article in enumerate(cc_news) if idx in eudist_indices10k
]
# Out:
# CPU times: user 48.1 s, sys: 902 ms, total: 49 s
# Wall time: 49 s

# %%
with open(os.path.join("data", "cc_eudist10k.json"), "w") as outfile:
    json.dump(cc_eudist10k, outfile)

# %%
with open(os.path.join("data", "cc_eudist10k.txt"), "w") as outfile:
    json.dump(cc_eudist10k, outfile)

# %% [markdown]
# ## Word Embedding Diversity / Mean pairwise cosine distance (Palumbo et al. 2020)

# %%
from sklearn.metrics import pairwise_distances_chunked
from operator import itemgetter
from itertools import chain
from tqdm import tqdm
import numpy as np
import json
import time
import os

# %%
arr_path = os.path.join("data", "cc_arrays")

# %%
for roots, dirs, files in os.walk(arr_path):
    
    print(len(files))

    indices = [
        int(filename[2:-4]) for filename in files
    ]
    
    filepaths = [
        os.path.join(arr_path, filename) for filename in files
    ]
    
    idx2path = sorted(
        list(zip(indices, filepaths)),
        key = itemgetter(0)
    )
    
    print(idx2path[-1])
# Out:
# 703532
# (703531, 'data/cc_arrays/cc703531.npy')

# %%
cc_array = np.zeros((len(idx2path), 768))

for idx, filepath in tqdm(idx2path):
    
    arr = np.load(filepath)
    cc_array[idx] = arr
# Out:
# 100%|█████████████████████████████████| 703532/703532 [01:41<00:00, 6928.59it/s]

# %%
# %%time

cc_wed_chunked = []
it = 0
tock = time.time()
m_start = 0
m_end = 0

for chunk in pairwise_distances_chunked(cc_array, metric="cosine"):
    
    cc_wed_chunked.append(np.mean(chunk, axis=1).tolist())
    
    it += 1
    tick = time.time()
    m_start = m_end
    m_end += chunk.shape[0]
    
    print(f"Iter {it}  :  Rows {m_start}-{m_end}  :  {tick - tock} seconds elapsed")
    tock = time.time()
# Out:
# Iter 1  :  Rows 0-190  :  2.7233941555023193 seconds elapsed
# Iter 2  :  Rows 190-380  :  3.185492992401123 seconds elapsed
# Iter 3  :  Rows 380-570  :  2.486224889755249 seconds elapsed
# Iter 4  :  Rows 570-760  :  2.200418710708618 seconds elapsed
# Iter 5  :  Rows 760-950  :  2.2093570232391357 seconds elapsed
# Iter 6  :  Rows 950-1140  :  2.2308738231658936 seconds elapsed
# Iter 7  :  Rows 1140-1330  :  2.2043309211730957 seconds elapsed
# Iter 8  :  Rows 1330-1520  :  2.2553868293762207 seconds elapsed
# Iter 9  :  Rows 1520-1710  :  2.2104079723358154 seconds elapsed
# Iter 10  :  Rows 1710-1900  :  2.191317081451416 seconds elapsed
# Iter 11  :  Rows 1900-2090  :  2.2452123165130615 seconds elapsed
# Iter 12  :  Rows 2090-2280  :  2.214040994644165 seconds elapsed
# Iter 13  :  Rows 2280-2470  :  2.2247989177703857 seconds elapsed
# Iter 14  :  Rows 2470-2660  :  2.2463490962982178 seconds elapsed
# Iter 15  :  Rows 2660-2850  :  2.229434013366699 seconds elapsed
# Iter 16  :  Rows 2850-3040  :  2.2211310863494873 seconds elapsed
# Iter 17  :  Rows 3040-3230  :  2.2167320251464844 seconds elapsed
# Iter 18  :  Rows 3230-3420  :  2.204240083694458 seconds elapsed
# Iter 19  :  Rows 3420-3610  :  2.214186668395996 seconds elapsed
# Iter 20  :  Rows 3610-3800  :  2.213076114654541 seconds elapsed
# Iter 21  :  Rows 3800-3990  :  2.2079379558563232 seconds elapsed
# Iter 22  :  Rows 3990-4180  :  2.2481610774993896 seconds elapsed
# Iter 23  :  Rows 4180-4370  :  2.1906089782714844 seconds elapsed
# Iter 24  :  Rows 4370-4560  :  2.218417167663574 seconds elapsed
# Iter 25  :  Rows 4560-4750  :  2.219180107116699 seconds elapsed
# Iter 26  :  Rows 4750-4940  :  2.213095188140869 seconds elapsed
# Iter 27  :  Rows 4940-5130  :  2.2122628688812256 seconds elapsed
# Iter 28  :  Rows 5130-5320  :  2.2308871746063232 seconds elapsed
# Iter 29  :  Rows 5320-5510  :  2.208662986755371 seconds elapsed
# Iter 30  :  Rows 5510-5700  :  2.2014970779418945 seconds elapsed
# Iter 31  :  Rows 5700-5890  :  2.205352783203125 seconds elapsed
# Iter 32  :  Rows 5890-6080  :  2.2107369899749756 seconds elapsed
# Iter 33  :  Rows 6080-6270  :  2.2326560020446777 seconds elapsed
# Iter 34  :  Rows 6270-6460  :  2.2423288822174072 seconds elapsed
# Iter 35  :  Rows 6460-6650  :  2.207987070083618 seconds elapsed
# Iter 36  :  Rows 6650-6840  :  2.222111940383911 seconds elapsed
# Iter 37  :  Rows 6840-7030  :  2.214653968811035 seconds elapsed
# Iter 38  :  Rows 7030-7220  :  2.204461097717285 seconds elapsed
# Iter 39  :  Rows 7220-7410  :  2.198713779449463 seconds elapsed
# Iter 40  :  Rows 7410-7600  :  2.214155912399292 seconds elapsed
# Iter 41  :  Rows 7600-7790  :  2.2429449558258057 seconds elapsed
# Iter 42  :  Rows 7790-7980  :  2.2302169799804688 seconds elapsed
# Iter 43  :  Rows 7980-8170  :  2.2302498817443848 seconds elapsed
# Iter 44  :  Rows 8170-8360  :  2.2138962745666504 seconds elapsed
# Iter 45  :  Rows 8360-8550  :  2.2395339012145996 seconds elapsed
# Iter 46  :  Rows 8550-8740  :  2.208927869796753 seconds elapsed
# Iter 47  :  Rows 8740-8930  :  2.2185659408569336 seconds elapsed
# Iter 48  :  Rows 8930-9120  :  2.2075939178466797 seconds elapsed
# Iter 49  :  Rows 9120-9310  :  2.2286789417266846 seconds elapsed
# Iter 50  :  Rows 9310-9500  :  2.2163681983947754 seconds elapsed
# Iter 51  :  Rows 9500-9690  :  2.202023983001709 seconds elapsed
# Iter 52  :  Rows 9690-9880  :  2.226224899291992 seconds elapsed
# Iter 53  :  Rows 9880-10070  :  2.2051291465759277 seconds elapsed
# Iter 54  :  Rows 10070-10260  :  2.2171661853790283 seconds elapsed
# Iter 55  :  Rows 10260-10450  :  2.2107291221618652 seconds elapsed
# Iter 56  :  Rows 10450-10640  :  2.215020179748535 seconds elapsed
# Iter 57  :  Rows 10640-10830  :  2.21228289604187 seconds elapsed
# Iter 58  :  Rows 10830-11020  :  2.2225258350372314 seconds elapsed
# Iter 59  :  Rows 11020-11210  :  2.210891008377075 seconds elapsed
# Iter 60  :  Rows 11210-11400  :  2.2490651607513428 seconds elapsed
# Iter 61  :  Rows 11400-11590  :  2.2206051349639893 seconds elapsed
# Iter 62  :  Rows 11590-11780  :  2.234442949295044 seconds elapsed
# Iter 63  :  Rows 11780-11970  :  2.2045323848724365 seconds elapsed
# Iter 64  :  Rows 11970-12160  :  2.233999013900757 seconds elapsed
# Iter 65  :  Rows 12160-12350  :  2.2287070751190186 seconds elapsed
# Iter 66  :  Rows 12350-12540  :  2.1973109245300293 seconds elapsed
# Iter 67  :  Rows 12540-12730  :  2.229666233062744 seconds elapsed
# Iter 68  :  Rows 12730-12920  :  2.234349012374878 seconds elapsed
# Iter 69  :  Rows 12920-13110  :  2.220538854598999 seconds elapsed
# Iter 70  :  Rows 13110-13300  :  2.217103958129883 seconds elapsed
# Iter 71  :  Rows 13300-13490  :  2.2234110832214355 seconds elapsed
# Iter 72  :  Rows 13490-13680  :  2.2292640209198 seconds elapsed
# Iter 73  :  Rows 13680-13870  :  2.2374091148376465 seconds elapsed
# Iter 74  :  Rows 13870-14060  :  2.2205047607421875 seconds elapsed
# Iter 75  :  Rows 14060-14250  :  2.20524001121521 seconds elapsed
# Iter 76  :  Rows 14250-14440  :  2.237231969833374 seconds elapsed
# Iter 77  :  Rows 14440-14630  :  2.22263503074646 seconds elapsed
# Iter 78  :  Rows 14630-14820  :  2.2369232177734375 seconds elapsed
# Iter 79  :  Rows 14820-15010  :  2.2433180809020996 seconds elapsed
# Iter 80  :  Rows 15010-15200  :  2.252323865890503 seconds elapsed
# Iter 81  :  Rows 15200-15390  :  2.27650785446167 seconds elapsed
# Iter 82  :  Rows 15390-15580  :  2.317640781402588 seconds elapsed
# Iter 83  :  Rows 15580-15770  :  2.2424728870391846 seconds elapsed
# Iter 84  :  Rows 15770-15960  :  2.238569974899292 seconds elapsed
# Iter 85  :  Rows 15960-16150  :  2.220643997192383 seconds elapsed
# Iter 86  :  Rows 16150-16340  :  2.2261359691619873 seconds elapsed
# Iter 87  :  Rows 16340-16530  :  2.2528581619262695 seconds elapsed
# Iter 88  :  Rows 16530-16720  :  2.2281031608581543 seconds elapsed
# Iter 89  :  Rows 16720-16910  :  2.2657079696655273 seconds elapsed
# Iter 90  :  Rows 16910-17100  :  2.238534927368164 seconds elapsed
# Iter 91  :  Rows 17100-17290  :  2.2529468536376953 seconds elapsed
# Iter 92  :  Rows 17290-17480  :  2.2859320640563965 seconds elapsed
# Iter 93  :  Rows 17480-17670  :  2.2613329887390137 seconds elapsed
# Iter 94  :  Rows 17670-17860  :  2.2639307975769043 seconds elapsed
# Iter 95  :  Rows 17860-18050  :  2.3046481609344482 seconds elapsed
# Iter 96  :  Rows 18050-18240  :  2.2528529167175293 seconds elapsed
# Iter 97  :  Rows 18240-18430  :  2.2597720623016357 seconds elapsed
# Iter 98  :  Rows 18430-18620  :  2.2616922855377197 seconds elapsed
# Iter 99  :  Rows 18620-18810  :  2.219752073287964 seconds elapsed
# Iter 100  :  Rows 18810-19000  :  2.243067979812622 seconds elapsed
# Iter 101  :  Rows 19000-19190  :  2.240464210510254 seconds elapsed
# Iter 102  :  Rows 19190-19380  :  2.2562448978424072 seconds elapsed
# Iter 103  :  Rows 19380-19570  :  2.231471061706543 seconds elapsed
# Iter 104  :  Rows 19570-19760  :  2.2397139072418213 seconds elapsed
# Iter 105  :  Rows 19760-19950  :  2.2227611541748047 seconds elapsed
# Iter 106  :  Rows 19950-20140  :  2.227452039718628 seconds elapsed
# Iter 107  :  Rows 20140-20330  :  2.251138687133789 seconds elapsed
# Iter 108  :  Rows 20330-20520  :  2.232128858566284 seconds elapsed
# Iter 109  :  Rows 20520-20710  :  2.256972074508667 seconds elapsed
# Iter 110  :  Rows 20710-20900  :  2.2658369541168213 seconds elapsed
# Iter 111  :  Rows 20900-21090  :  2.277827739715576 seconds elapsed
# Iter 112  :  Rows 21090-21280  :  2.2330031394958496 seconds elapsed
# Iter 113  :  Rows 21280-21470  :  2.3066508769989014 seconds elapsed
# Iter 114  :  Rows 21470-21660  :  2.49814510345459 seconds elapsed
# Iter 115  :  Rows 21660-21850  :  2.3134379386901855 seconds elapsed
# Iter 116  :  Rows 21850-22040  :  2.2945539951324463 seconds elapsed
# Iter 117  :  Rows 22040-22230  :  2.222276210784912 seconds elapsed
# Iter 118  :  Rows 22230-22420  :  2.218712091445923 seconds elapsed
# Iter 119  :  Rows 22420-22610  :  2.2603437900543213 seconds elapsed
# Iter 120  :  Rows 22610-22800  :  2.238044023513794 seconds elapsed
# Iter 121  :  Rows 22800-22990  :  2.2346701622009277 seconds elapsed
# Iter 122  :  Rows 22990-23180  :  2.22065806388855 seconds elapsed
# Iter 123  :  Rows 23180-23370  :  2.2356619834899902 seconds elapsed
# Iter 124  :  Rows 23370-23560  :  2.2567250728607178 seconds elapsed
# Iter 125  :  Rows 23560-23750  :  2.230362892150879 seconds elapsed
# Iter 126  :  Rows 23750-23940  :  2.227579116821289 seconds elapsed
# Iter 127  :  Rows 23940-24130  :  2.211789846420288 seconds elapsed
# Iter 128  :  Rows 24130-24320  :  2.211935043334961 seconds elapsed
# Iter 129  :  Rows 24320-24510  :  2.222219944000244 seconds elapsed
# Iter 130  :  Rows 24510-24700  :  2.2193939685821533 seconds elapsed
# Iter 131  :  Rows 24700-24890  :  2.190221071243286 seconds elapsed
# Iter 132  :  Rows 24890-25080  :  2.2092318534851074 seconds elapsed
# Iter 133  :  Rows 25080-25270  :  2.199831962585449 seconds elapsed
# Iter 134  :  Rows 25270-25460  :  2.2603700160980225 seconds elapsed
# Iter 135  :  Rows 25460-25650  :  2.2467548847198486 seconds elapsed
# Iter 136  :  Rows 25650-25840  :  2.2310068607330322 seconds elapsed
# Iter 137  :  Rows 25840-26030  :  2.2088911533355713 seconds elapsed
# Iter 138  :  Rows 26030-26220  :  2.2087790966033936 seconds elapsed
# Iter 139  :  Rows 26220-26410  :  2.204730987548828 seconds elapsed
# Iter 140  :  Rows 26410-26600  :  2.230774164199829 seconds elapsed
# Iter 141  :  Rows 26600-26790  :  2.2178187370300293 seconds elapsed
# Iter 142  :  Rows 26790-26980  :  2.229959011077881 seconds elapsed
# Iter 143  :  Rows 26980-27170  :  2.212553024291992 seconds elapsed
# Iter 144  :  Rows 27170-27360  :  2.195708751678467 seconds elapsed
# Iter 145  :  Rows 27360-27550  :  2.218165874481201 seconds elapsed
# Iter 146  :  Rows 27550-27740  :  2.2112009525299072 seconds elapsed
# Iter 147  :  Rows 27740-27930  :  2.2039079666137695 seconds elapsed
# Iter 148  :  Rows 27930-28120  :  2.203589916229248 seconds elapsed
# Iter 149  :  Rows 28120-28310  :  2.2126681804656982 seconds elapsed
# Iter 150  :  Rows 28310-28500  :  2.2059268951416016 seconds elapsed
# Iter 151  :  Rows 28500-28690  :  2.2251908779144287 seconds elapsed
# Iter 152  :  Rows 28690-28880  :  2.192779064178467 seconds elapsed
# Iter 153  :  Rows 28880-29070  :  2.19148588180542 seconds elapsed
# Iter 154  :  Rows 29070-29260  :  2.2517828941345215 seconds elapsed
# Iter 155  :  Rows 29260-29450  :  2.2124929428100586 seconds elapsed
# Iter 156  :  Rows 29450-29640  :  2.2048048973083496 seconds elapsed
# Iter 157  :  Rows 29640-29830  :  2.201829195022583 seconds elapsed
# Iter 158  :  Rows 29830-30020  :  2.2031350135803223 seconds elapsed
# Iter 159  :  Rows 30020-30210  :  2.226254940032959 seconds elapsed
# Iter 160  :  Rows 30210-30400  :  2.208256959915161 seconds elapsed
# Iter 161  :  Rows 30400-30590  :  2.209321975708008 seconds elapsed
# Iter 162  :  Rows 30590-30780  :  2.2290940284729004 seconds elapsed
# Iter 163  :  Rows 30780-30970  :  2.2176120281219482 seconds elapsed
# Iter 164  :  Rows 30970-31160  :  2.20719313621521 seconds elapsed
# Iter 165  :  Rows 31160-31350  :  2.217413902282715 seconds elapsed
# Iter 166  :  Rows 31350-31540  :  2.197866916656494 seconds elapsed
# Iter 167  :  Rows 31540-31730  :  2.1912970542907715 seconds elapsed
# Iter 168  :  Rows 31730-31920  :  2.197974920272827 seconds elapsed
# Iter 169  :  Rows 31920-32110  :  2.221472978591919 seconds elapsed
# Iter 170  :  Rows 32110-32300  :  2.2140259742736816 seconds elapsed
# Iter 171  :  Rows 32300-32490  :  2.2363929748535156 seconds elapsed
# Iter 172  :  Rows 32490-32680  :  2.21763277053833 seconds elapsed
# Iter 173  :  Rows 32680-32870  :  2.221329927444458 seconds elapsed
# Iter 174  :  Rows 32870-33060  :  2.2085461616516113 seconds elapsed
# Iter 175  :  Rows 33060-33250  :  2.2208590507507324 seconds elapsed
# Iter 176  :  Rows 33250-33440  :  2.198214054107666 seconds elapsed
# Iter 177  :  Rows 33440-33630  :  2.218625068664551 seconds elapsed
# Iter 178  :  Rows 33630-33820  :  2.2169132232666016 seconds elapsed
# Iter 179  :  Rows 33820-34010  :  2.2007570266723633 seconds elapsed
# Iter 180  :  Rows 34010-34200  :  2.218729019165039 seconds elapsed
# Iter 181  :  Rows 34200-34390  :  2.2124288082122803 seconds elapsed
# Iter 182  :  Rows 34390-34580  :  2.211930751800537 seconds elapsed
# Iter 183  :  Rows 34580-34770  :  2.2235119342803955 seconds elapsed
# Iter 184  :  Rows 34770-34960  :  2.229745864868164 seconds elapsed
# Iter 185  :  Rows 34960-35150  :  2.221273899078369 seconds elapsed
# Iter 186  :  Rows 35150-35340  :  2.2072770595550537 seconds elapsed
# Iter 187  :  Rows 35340-35530  :  2.218135118484497 seconds elapsed
# Iter 188  :  Rows 35530-35720  :  2.2440409660339355 seconds elapsed
# Iter 189  :  Rows 35720-35910  :  2.2175259590148926 seconds elapsed
# Iter 190  :  Rows 35910-36100  :  2.244542121887207 seconds elapsed
# Iter 191  :  Rows 36100-36290  :  2.2337682247161865 seconds elapsed
# Iter 192  :  Rows 36290-36480  :  2.2285068035125732 seconds elapsed
# Iter 193  :  Rows 36480-36670  :  2.189365863800049 seconds elapsed
# Iter 194  :  Rows 36670-36860  :  2.213425874710083 seconds elapsed
# Iter 195  :  Rows 36860-37050  :  2.23575496673584 seconds elapsed
# Iter 196  :  Rows 37050-37240  :  2.20320987701416 seconds elapsed
# Iter 197  :  Rows 37240-37430  :  2.191464900970459 seconds elapsed
# Iter 198  :  Rows 37430-37620  :  2.1954166889190674 seconds elapsed
# Iter 199  :  Rows 37620-37810  :  2.221850872039795 seconds elapsed
# Iter 200  :  Rows 37810-38000  :  2.1985092163085938 seconds elapsed
# Iter 201  :  Rows 38000-38190  :  2.228008985519409 seconds elapsed
# Iter 202  :  Rows 38190-38380  :  2.2253220081329346 seconds elapsed
# Iter 203  :  Rows 38380-38570  :  2.2256128787994385 seconds elapsed
# Iter 204  :  Rows 38570-38760  :  2.2377028465270996 seconds elapsed
# Iter 205  :  Rows 38760-38950  :  2.2338688373565674 seconds elapsed
# Iter 206  :  Rows 38950-39140  :  2.235469102859497 seconds elapsed
# Iter 207  :  Rows 39140-39330  :  2.1996121406555176 seconds elapsed
# Iter 208  :  Rows 39330-39520  :  2.198438882827759 seconds elapsed
# Iter 209  :  Rows 39520-39710  :  2.2397449016571045 seconds elapsed
# Iter 210  :  Rows 39710-39900  :  2.229595184326172 seconds elapsed
# Iter 211  :  Rows 39900-40090  :  2.2301840782165527 seconds elapsed
# Iter 212  :  Rows 40090-40280  :  2.226356029510498 seconds elapsed
# Iter 213  :  Rows 40280-40470  :  2.2178170680999756 seconds elapsed
# Iter 214  :  Rows 40470-40660  :  2.2273731231689453 seconds elapsed
# Iter 215  :  Rows 40660-40850  :  2.2179038524627686 seconds elapsed
# Iter 216  :  Rows 40850-41040  :  2.2272870540618896 seconds elapsed
# Iter 217  :  Rows 41040-41230  :  2.2181291580200195 seconds elapsed
# Iter 218  :  Rows 41230-41420  :  2.248806953430176 seconds elapsed
# Iter 219  :  Rows 41420-41610  :  2.222891092300415 seconds elapsed
# Iter 220  :  Rows 41610-41800  :  2.222752809524536 seconds elapsed
# Iter 221  :  Rows 41800-41990  :  2.261093854904175 seconds elapsed
# Iter 222  :  Rows 41990-42180  :  2.2424681186676025 seconds elapsed
# Iter 223  :  Rows 42180-42370  :  2.2318778038024902 seconds elapsed
# Iter 224  :  Rows 42370-42560  :  2.216697931289673 seconds elapsed
# Iter 225  :  Rows 42560-42750  :  2.2153568267822266 seconds elapsed
# Iter 226  :  Rows 42750-42940  :  2.237597942352295 seconds elapsed
# Iter 227  :  Rows 42940-43130  :  2.2305541038513184 seconds elapsed
# Iter 228  :  Rows 43130-43320  :  2.2447898387908936 seconds elapsed
# Iter 229  :  Rows 43320-43510  :  2.200335741043091 seconds elapsed
# Iter 230  :  Rows 43510-43700  :  2.2056429386138916 seconds elapsed
# Iter 231  :  Rows 43700-43890  :  2.2152769565582275 seconds elapsed
# Iter 232  :  Rows 43890-44080  :  2.2518908977508545 seconds elapsed
# Iter 233  :  Rows 44080-44270  :  2.2240569591522217 seconds elapsed
# Iter 234  :  Rows 44270-44460  :  2.2043509483337402 seconds elapsed
# Iter 235  :  Rows 44460-44650  :  2.2221949100494385 seconds elapsed
# Iter 236  :  Rows 44650-44840  :  2.21551513671875 seconds elapsed
# Iter 237  :  Rows 44840-45030  :  2.235570192337036 seconds elapsed
# Iter 238  :  Rows 45030-45220  :  2.2203409671783447 seconds elapsed
# Iter 239  :  Rows 45220-45410  :  2.209077835083008 seconds elapsed
# Iter 240  :  Rows 45410-45600  :  2.208366870880127 seconds elapsed
# Iter 241  :  Rows 45600-45790  :  2.221574068069458 seconds elapsed
# Iter 242  :  Rows 45790-45980  :  2.218284845352173 seconds elapsed
# Iter 243  :  Rows 45980-46170  :  2.2415852546691895 seconds elapsed
# Iter 244  :  Rows 46170-46360  :  2.2400572299957275 seconds elapsed
# Iter 245  :  Rows 46360-46550  :  2.2135531902313232 seconds elapsed
# Iter 246  :  Rows 46550-46740  :  2.218379020690918 seconds elapsed
# Iter 247  :  Rows 46740-46930  :  2.227048873901367 seconds elapsed
# Iter 248  :  Rows 46930-47120  :  2.214615821838379 seconds elapsed
# Iter 249  :  Rows 47120-47310  :  2.2035562992095947 seconds elapsed
# Iter 250  :  Rows 47310-47500  :  2.221041202545166 seconds elapsed
# Iter 251  :  Rows 47500-47690  :  2.212592840194702 seconds elapsed
# Iter 252  :  Rows 47690-47880  :  2.2212719917297363 seconds elapsed
# Iter 253  :  Rows 47880-48070  :  2.2128329277038574 seconds elapsed
# Iter 254  :  Rows 48070-48260  :  2.2214131355285645 seconds elapsed
# Iter 255  :  Rows 48260-48450  :  2.2418320178985596 seconds elapsed
# Iter 256  :  Rows 48450-48640  :  2.207494020462036 seconds elapsed
# Iter 257  :  Rows 48640-48830  :  2.2243571281433105 seconds elapsed
# Iter 258  :  Rows 48830-49020  :  2.22377872467041 seconds elapsed
# Iter 259  :  Rows 49020-49210  :  2.203064203262329 seconds elapsed
# Iter 260  :  Rows 49210-49400  :  2.209160089492798 seconds elapsed
# Iter 261  :  Rows 49400-49590  :  2.1962671279907227 seconds elapsed
# Iter 262  :  Rows 49590-49780  :  2.2249841690063477 seconds elapsed
# Iter 263  :  Rows 49780-49970  :  2.217543840408325 seconds elapsed
# Iter 264  :  Rows 49970-50160  :  2.244119644165039 seconds elapsed
# Iter 265  :  Rows 50160-50350  :  2.2139129638671875 seconds elapsed
# Iter 266  :  Rows 50350-50540  :  2.221116065979004 seconds elapsed
# Iter 267  :  Rows 50540-50730  :  2.205341100692749 seconds elapsed
# Iter 268  :  Rows 50730-50920  :  2.206512928009033 seconds elapsed
# Iter 269  :  Rows 50920-51110  :  2.2340500354766846 seconds elapsed
# Iter 270  :  Rows 51110-51300  :  2.217663049697876 seconds elapsed
# Iter 271  :  Rows 51300-51490  :  2.2069859504699707 seconds elapsed
# Iter 272  :  Rows 51490-51680  :  2.2073137760162354 seconds elapsed
# Iter 273  :  Rows 51680-51870  :  2.2205262184143066 seconds elapsed
# Iter 274  :  Rows 51870-52060  :  2.2225940227508545 seconds elapsed
# Iter 275  :  Rows 52060-52250  :  2.239809989929199 seconds elapsed
# Iter 276  :  Rows 52250-52440  :  2.220355987548828 seconds elapsed
# Iter 277  :  Rows 52440-52630  :  2.225984811782837 seconds elapsed
# Iter 278  :  Rows 52630-52820  :  2.207146167755127 seconds elapsed
# Iter 279  :  Rows 52820-53010  :  2.231043815612793 seconds elapsed
# Iter 280  :  Rows 53010-53200  :  2.244626760482788 seconds elapsed
# Iter 281  :  Rows 53200-53390  :  2.2333600521087646 seconds elapsed
# Iter 282  :  Rows 53390-53580  :  2.233436107635498 seconds elapsed
# Iter 283  :  Rows 53580-53770  :  2.2195749282836914 seconds elapsed
# Iter 284  :  Rows 53770-53960  :  2.2351741790771484 seconds elapsed
# Iter 285  :  Rows 53960-54150  :  2.233412265777588 seconds elapsed
# Iter 286  :  Rows 54150-54340  :  2.233962059020996 seconds elapsed
# Iter 287  :  Rows 54340-54530  :  2.2310469150543213 seconds elapsed
# Iter 288  :  Rows 54530-54720  :  2.21162486076355 seconds elapsed
# Iter 289  :  Rows 54720-54910  :  2.207911252975464 seconds elapsed
# Iter 290  :  Rows 54910-55100  :  2.2182419300079346 seconds elapsed
# Iter 291  :  Rows 55100-55290  :  2.229702949523926 seconds elapsed
# Iter 292  :  Rows 55290-55480  :  2.2213728427886963 seconds elapsed
# Iter 293  :  Rows 55480-55670  :  2.2171356678009033 seconds elapsed
# Iter 294  :  Rows 55670-55860  :  2.2192299365997314 seconds elapsed
# Iter 295  :  Rows 55860-56050  :  2.2066268920898438 seconds elapsed
# Iter 296  :  Rows 56050-56240  :  2.2430548667907715 seconds elapsed
# Iter 297  :  Rows 56240-56430  :  2.2248382568359375 seconds elapsed
# Iter 298  :  Rows 56430-56620  :  2.2205700874328613 seconds elapsed
# Iter 299  :  Rows 56620-56810  :  2.2180511951446533 seconds elapsed
# Iter 300  :  Rows 56810-57000  :  2.2199082374572754 seconds elapsed
# Iter 301  :  Rows 57000-57190  :  2.216521978378296 seconds elapsed
# Iter 302  :  Rows 57190-57380  :  2.215946912765503 seconds elapsed
# Iter 303  :  Rows 57380-57570  :  2.210829257965088 seconds elapsed
# Iter 304  :  Rows 57570-57760  :  2.2319788932800293 seconds elapsed
# Iter 305  :  Rows 57760-57950  :  2.212256669998169 seconds elapsed
# Iter 306  :  Rows 57950-58140  :  2.221194267272949 seconds elapsed
# Iter 307  :  Rows 58140-58330  :  2.253434181213379 seconds elapsed
# Iter 308  :  Rows 58330-58520  :  2.222545862197876 seconds elapsed
# Iter 309  :  Rows 58520-58710  :  2.2235710620880127 seconds elapsed
# Iter 310  :  Rows 58710-58900  :  2.226184129714966 seconds elapsed
# Iter 311  :  Rows 58900-59090  :  2.2407000064849854 seconds elapsed
# Iter 312  :  Rows 59090-59280  :  2.232260227203369 seconds elapsed
# Iter 313  :  Rows 59280-59470  :  2.2133398056030273 seconds elapsed
# Iter 314  :  Rows 59470-59660  :  2.21566104888916 seconds elapsed
# Iter 315  :  Rows 59660-59850  :  2.221614122390747 seconds elapsed
# Iter 316  :  Rows 59850-60040  :  2.2418909072875977 seconds elapsed
# Iter 317  :  Rows 60040-60230  :  2.2206010818481445 seconds elapsed
# Iter 318  :  Rows 60230-60420  :  2.229193925857544 seconds elapsed
# Iter 319  :  Rows 60420-60610  :  2.2356631755828857 seconds elapsed
# Iter 320  :  Rows 60610-60800  :  2.2171881198883057 seconds elapsed
# Iter 321  :  Rows 60800-60990  :  2.201545000076294 seconds elapsed
# Iter 322  :  Rows 60990-61180  :  2.2255749702453613 seconds elapsed
# Iter 323  :  Rows 61180-61370  :  2.2230632305145264 seconds elapsed
# Iter 324  :  Rows 61370-61560  :  2.212517261505127 seconds elapsed
# Iter 325  :  Rows 61560-61750  :  2.216839075088501 seconds elapsed
# Iter 326  :  Rows 61750-61940  :  2.1997601985931396 seconds elapsed
# Iter 327  :  Rows 61940-62130  :  2.2248990535736084 seconds elapsed
# Iter 328  :  Rows 62130-62320  :  2.2138512134552 seconds elapsed
# Iter 329  :  Rows 62320-62510  :  2.219224214553833 seconds elapsed
# Iter 330  :  Rows 62510-62700  :  2.2342488765716553 seconds elapsed
# Iter 331  :  Rows 62700-62890  :  2.2020070552825928 seconds elapsed
# Iter 332  :  Rows 62890-63080  :  2.2083678245544434 seconds elapsed
# Iter 333  :  Rows 63080-63270  :  2.222775936126709 seconds elapsed
# Iter 334  :  Rows 63270-63460  :  2.212512969970703 seconds elapsed
# Iter 335  :  Rows 63460-63650  :  2.2213640213012695 seconds elapsed
# Iter 336  :  Rows 63650-63840  :  2.2308499813079834 seconds elapsed
# Iter 337  :  Rows 63840-64030  :  2.244361162185669 seconds elapsed
# Iter 338  :  Rows 64030-64220  :  2.2222390174865723 seconds elapsed
# Iter 339  :  Rows 64220-64410  :  2.202394723892212 seconds elapsed
# Iter 340  :  Rows 64410-64600  :  2.1974589824676514 seconds elapsed
# Iter 341  :  Rows 64600-64790  :  2.228496789932251 seconds elapsed
# Iter 342  :  Rows 64790-64980  :  2.2376389503479004 seconds elapsed
# Iter 343  :  Rows 64980-65170  :  2.2354769706726074 seconds elapsed
# Iter 344  :  Rows 65170-65360  :  2.2366459369659424 seconds elapsed
# Iter 345  :  Rows 65360-65550  :  2.2241342067718506 seconds elapsed
# Iter 346  :  Rows 65550-65740  :  2.2184808254241943 seconds elapsed
# Iter 347  :  Rows 65740-65930  :  2.2174198627471924 seconds elapsed
# Iter 348  :  Rows 65930-66120  :  2.2052650451660156 seconds elapsed
# Iter 349  :  Rows 66120-66310  :  2.206033945083618 seconds elapsed
# Iter 350  :  Rows 66310-66500  :  2.220339298248291 seconds elapsed
# Iter 351  :  Rows 66500-66690  :  2.2421188354492188 seconds elapsed
# Iter 352  :  Rows 66690-66880  :  2.2138659954071045 seconds elapsed
# Iter 353  :  Rows 66880-67070  :  2.2271311283111572 seconds elapsed
# Iter 354  :  Rows 67070-67260  :  2.228550910949707 seconds elapsed
# Iter 355  :  Rows 67260-67450  :  2.2205209732055664 seconds elapsed
# Iter 356  :  Rows 67450-67640  :  2.227748155593872 seconds elapsed
# Iter 357  :  Rows 67640-67830  :  2.2201642990112305 seconds elapsed
# Iter 358  :  Rows 67830-68020  :  2.2157697677612305 seconds elapsed
# Iter 359  :  Rows 68020-68210  :  2.2098708152770996 seconds elapsed
# Iter 360  :  Rows 68210-68400  :  2.2381176948547363 seconds elapsed
# Iter 361  :  Rows 68400-68590  :  2.2294769287109375 seconds elapsed
# Iter 362  :  Rows 68590-68780  :  2.226716995239258 seconds elapsed
# Iter 363  :  Rows 68780-68970  :  2.2226099967956543 seconds elapsed
# Iter 364  :  Rows 68970-69160  :  2.2157440185546875 seconds elapsed
# Iter 365  :  Rows 69160-69350  :  2.206223964691162 seconds elapsed
# Iter 366  :  Rows 69350-69540  :  2.2147817611694336 seconds elapsed
# Iter 367  :  Rows 69540-69730  :  2.205334186553955 seconds elapsed
# Iter 368  :  Rows 69730-69920  :  2.2416298389434814 seconds elapsed
# Iter 369  :  Rows 69920-70110  :  2.208853006362915 seconds elapsed
# Iter 370  :  Rows 70110-70300  :  2.234790086746216 seconds elapsed
# Iter 371  :  Rows 70300-70490  :  2.2193338871002197 seconds elapsed
# Iter 372  :  Rows 70490-70680  :  2.2389068603515625 seconds elapsed
# Iter 373  :  Rows 70680-70870  :  2.2203521728515625 seconds elapsed
# Iter 374  :  Rows 70870-71060  :  2.22337007522583 seconds elapsed
# Iter 375  :  Rows 71060-71250  :  2.22879695892334 seconds elapsed
# Iter 376  :  Rows 71250-71440  :  2.2092580795288086 seconds elapsed
# Iter 377  :  Rows 71440-71630  :  2.2148258686065674 seconds elapsed
# Iter 378  :  Rows 71630-71820  :  2.2133986949920654 seconds elapsed
# Iter 379  :  Rows 71820-72010  :  2.223508834838867 seconds elapsed
# Iter 380  :  Rows 72010-72200  :  2.237236976623535 seconds elapsed
# Iter 381  :  Rows 72200-72390  :  2.226686954498291 seconds elapsed
# Iter 382  :  Rows 72390-72580  :  2.2298169136047363 seconds elapsed
# Iter 383  :  Rows 72580-72770  :  2.2120158672332764 seconds elapsed
# Iter 384  :  Rows 72770-72960  :  2.2194979190826416 seconds elapsed
# Iter 385  :  Rows 72960-73150  :  2.2108969688415527 seconds elapsed
# Iter 386  :  Rows 73150-73340  :  2.217042922973633 seconds elapsed
# Iter 387  :  Rows 73340-73530  :  2.2084908485412598 seconds elapsed
# Iter 388  :  Rows 73530-73720  :  2.2271039485931396 seconds elapsed
# Iter 389  :  Rows 73720-73910  :  2.2080881595611572 seconds elapsed
# Iter 390  :  Rows 73910-74100  :  2.2068419456481934 seconds elapsed
# Iter 391  :  Rows 74100-74290  :  2.2112879753112793 seconds elapsed
# Iter 392  :  Rows 74290-74480  :  2.2107601165771484 seconds elapsed
# Iter 393  :  Rows 74480-74670  :  2.2075870037078857 seconds elapsed
# Iter 394  :  Rows 74670-74860  :  2.226022958755493 seconds elapsed
# Iter 395  :  Rows 74860-75050  :  2.2370290756225586 seconds elapsed
# Iter 396  :  Rows 75050-75240  :  2.2267582416534424 seconds elapsed
# Iter 397  :  Rows 75240-75430  :  2.2129318714141846 seconds elapsed
# Iter 398  :  Rows 75430-75620  :  2.2196309566497803 seconds elapsed
# Iter 399  :  Rows 75620-75810  :  2.215507984161377 seconds elapsed
# Iter 400  :  Rows 75810-76000  :  2.2380998134613037 seconds elapsed
# Iter 401  :  Rows 76000-76190  :  2.1911509037017822 seconds elapsed
# Iter 402  :  Rows 76190-76380  :  2.207545042037964 seconds elapsed
# Iter 403  :  Rows 76380-76570  :  2.2192089557647705 seconds elapsed
# Iter 404  :  Rows 76570-76760  :  2.227501153945923 seconds elapsed
# Iter 405  :  Rows 76760-76950  :  2.1942989826202393 seconds elapsed
# Iter 406  :  Rows 76950-77140  :  2.2381649017333984 seconds elapsed
# Iter 407  :  Rows 77140-77330  :  2.2236781120300293 seconds elapsed
# Iter 408  :  Rows 77330-77520  :  2.2242331504821777 seconds elapsed
# Iter 409  :  Rows 77520-77710  :  2.2229981422424316 seconds elapsed
# Iter 410  :  Rows 77710-77900  :  2.241405963897705 seconds elapsed
# Iter 411  :  Rows 77900-78090  :  2.227264881134033 seconds elapsed
# Iter 412  :  Rows 78090-78280  :  2.197843074798584 seconds elapsed
# Iter 413  :  Rows 78280-78470  :  2.2064549922943115 seconds elapsed
# Iter 414  :  Rows 78470-78660  :  2.2183051109313965 seconds elapsed
# Iter 415  :  Rows 78660-78850  :  2.230120897293091 seconds elapsed
# Iter 416  :  Rows 78850-79040  :  2.2325868606567383 seconds elapsed
# Iter 417  :  Rows 79040-79230  :  2.2481510639190674 seconds elapsed
# Iter 418  :  Rows 79230-79420  :  2.2384278774261475 seconds elapsed
# Iter 419  :  Rows 79420-79610  :  2.215730905532837 seconds elapsed
# Iter 420  :  Rows 79610-79800  :  2.2088682651519775 seconds elapsed
# Iter 421  :  Rows 79800-79990  :  2.2206478118896484 seconds elapsed
# Iter 422  :  Rows 79990-80180  :  2.2299280166625977 seconds elapsed
# Iter 423  :  Rows 80180-80370  :  2.239108085632324 seconds elapsed
# Iter 424  :  Rows 80370-80560  :  2.218337059020996 seconds elapsed
# Iter 425  :  Rows 80560-80750  :  2.2037487030029297 seconds elapsed
# Iter 426  :  Rows 80750-80940  :  2.2276127338409424 seconds elapsed
# Iter 427  :  Rows 80940-81130  :  2.2191741466522217 seconds elapsed
# Iter 428  :  Rows 81130-81320  :  2.2092437744140625 seconds elapsed
# Iter 429  :  Rows 81320-81510  :  2.248617172241211 seconds elapsed
# Iter 430  :  Rows 81510-81700  :  2.23806095123291 seconds elapsed
# Iter 431  :  Rows 81700-81890  :  2.241741895675659 seconds elapsed
# Iter 432  :  Rows 81890-82080  :  2.2047977447509766 seconds elapsed
# Iter 433  :  Rows 82080-82270  :  2.246889114379883 seconds elapsed
# Iter 434  :  Rows 82270-82460  :  2.208004951477051 seconds elapsed
# Iter 435  :  Rows 82460-82650  :  2.217742919921875 seconds elapsed
# Iter 436  :  Rows 82650-82840  :  2.234163284301758 seconds elapsed
# Iter 437  :  Rows 82840-83030  :  2.2601687908172607 seconds elapsed
# Iter 438  :  Rows 83030-83220  :  2.202004909515381 seconds elapsed
# Iter 439  :  Rows 83220-83410  :  2.235146999359131 seconds elapsed
# Iter 440  :  Rows 83410-83600  :  2.2191128730773926 seconds elapsed
# Iter 441  :  Rows 83600-83790  :  2.223565101623535 seconds elapsed
# Iter 442  :  Rows 83790-83980  :  2.2423250675201416 seconds elapsed
# Iter 443  :  Rows 83980-84170  :  2.2182810306549072 seconds elapsed
# Iter 444  :  Rows 84170-84360  :  2.2256250381469727 seconds elapsed
# Iter 445  :  Rows 84360-84550  :  2.223327875137329 seconds elapsed
# Iter 446  :  Rows 84550-84740  :  2.2396600246429443 seconds elapsed
# Iter 447  :  Rows 84740-84930  :  2.2063241004943848 seconds elapsed
# Iter 448  :  Rows 84930-85120  :  2.2338039875030518 seconds elapsed
# Iter 449  :  Rows 85120-85310  :  2.225675106048584 seconds elapsed
# Iter 450  :  Rows 85310-85500  :  2.225761890411377 seconds elapsed
# Iter 451  :  Rows 85500-85690  :  2.230340003967285 seconds elapsed
# Iter 452  :  Rows 85690-85880  :  2.2063679695129395 seconds elapsed
# Iter 453  :  Rows 85880-86070  :  2.245241165161133 seconds elapsed
# Iter 454  :  Rows 86070-86260  :  2.247464895248413 seconds elapsed
# Iter 455  :  Rows 86260-86450  :  2.2149219512939453 seconds elapsed
# Iter 456  :  Rows 86450-86640  :  2.222416877746582 seconds elapsed
# Iter 457  :  Rows 86640-86830  :  2.2302749156951904 seconds elapsed
# Iter 458  :  Rows 86830-87020  :  2.2153589725494385 seconds elapsed
# Iter 459  :  Rows 87020-87210  :  2.2192399501800537 seconds elapsed
# Iter 460  :  Rows 87210-87400  :  2.216444969177246 seconds elapsed
# Iter 461  :  Rows 87400-87590  :  2.2282440662384033 seconds elapsed
# Iter 462  :  Rows 87590-87780  :  2.2141611576080322 seconds elapsed
# Iter 463  :  Rows 87780-87970  :  2.196192979812622 seconds elapsed
# Iter 464  :  Rows 87970-88160  :  2.2313790321350098 seconds elapsed
# Iter 465  :  Rows 88160-88350  :  2.2010202407836914 seconds elapsed
# Iter 466  :  Rows 88350-88540  :  2.2370622158050537 seconds elapsed
# Iter 467  :  Rows 88540-88730  :  2.2108218669891357 seconds elapsed
# Iter 468  :  Rows 88730-88920  :  2.201073169708252 seconds elapsed
# Iter 469  :  Rows 88920-89110  :  2.228447914123535 seconds elapsed
# Iter 470  :  Rows 89110-89300  :  2.2207460403442383 seconds elapsed
# Iter 471  :  Rows 89300-89490  :  2.2209837436676025 seconds elapsed
# Iter 472  :  Rows 89490-89680  :  2.234410047531128 seconds elapsed
# Iter 473  :  Rows 89680-89870  :  2.2182047367095947 seconds elapsed
# Iter 474  :  Rows 89870-90060  :  2.228062868118286 seconds elapsed
# Iter 475  :  Rows 90060-90250  :  2.2465240955352783 seconds elapsed
# Iter 476  :  Rows 90250-90440  :  2.233773946762085 seconds elapsed
# Iter 477  :  Rows 90440-90630  :  2.2075419425964355 seconds elapsed
# Iter 478  :  Rows 90630-90820  :  2.219823122024536 seconds elapsed
# Iter 479  :  Rows 90820-91010  :  2.2043709754943848 seconds elapsed
# Iter 480  :  Rows 91010-91200  :  2.2428431510925293 seconds elapsed
# Iter 481  :  Rows 91200-91390  :  2.2242889404296875 seconds elapsed
# Iter 482  :  Rows 91390-91580  :  2.1912779808044434 seconds elapsed
# Iter 483  :  Rows 91580-91770  :  2.2191920280456543 seconds elapsed
# Iter 484  :  Rows 91770-91960  :  2.199388027191162 seconds elapsed
# Iter 485  :  Rows 91960-92150  :  2.234147071838379 seconds elapsed
# Iter 486  :  Rows 92150-92340  :  2.2596731185913086 seconds elapsed
# Iter 487  :  Rows 92340-92530  :  2.2020750045776367 seconds elapsed
# Iter 488  :  Rows 92530-92720  :  2.240078926086426 seconds elapsed
# Iter 489  :  Rows 92720-92910  :  2.2175557613372803 seconds elapsed
# Iter 490  :  Rows 92910-93100  :  2.222337007522583 seconds elapsed
# Iter 491  :  Rows 93100-93290  :  2.2415549755096436 seconds elapsed
# Iter 492  :  Rows 93290-93480  :  2.2156970500946045 seconds elapsed
# Iter 493  :  Rows 93480-93670  :  2.2221100330352783 seconds elapsed
# Iter 494  :  Rows 93670-93860  :  2.22360897064209 seconds elapsed
# Iter 495  :  Rows 93860-94050  :  2.2169930934906006 seconds elapsed
# Iter 496  :  Rows 94050-94240  :  2.233288049697876 seconds elapsed
# Iter 497  :  Rows 94240-94430  :  2.225677251815796 seconds elapsed
# Iter 498  :  Rows 94430-94620  :  2.1862950325012207 seconds elapsed
# Iter 499  :  Rows 94620-94810  :  2.2140119075775146 seconds elapsed
# Iter 500  :  Rows 94810-95000  :  2.2281041145324707 seconds elapsed
# Iter 501  :  Rows 95000-95190  :  2.2431812286376953 seconds elapsed
# Iter 502  :  Rows 95190-95380  :  2.21871280670166 seconds elapsed
# Iter 503  :  Rows 95380-95570  :  2.236215114593506 seconds elapsed
# Iter 504  :  Rows 95570-95760  :  2.217334032058716 seconds elapsed
# Iter 505  :  Rows 95760-95950  :  2.239832878112793 seconds elapsed
# Iter 506  :  Rows 95950-96140  :  2.211682081222534 seconds elapsed
# Iter 507  :  Rows 96140-96330  :  2.2217531204223633 seconds elapsed
# Iter 508  :  Rows 96330-96520  :  2.231613874435425 seconds elapsed
# Iter 509  :  Rows 96520-96710  :  2.23294997215271 seconds elapsed
# Iter 510  :  Rows 96710-96900  :  2.211169958114624 seconds elapsed
# Iter 511  :  Rows 96900-97090  :  2.2412993907928467 seconds elapsed
# Iter 512  :  Rows 97090-97280  :  2.2257652282714844 seconds elapsed
# Iter 513  :  Rows 97280-97470  :  2.2087130546569824 seconds elapsed
# Iter 514  :  Rows 97470-97660  :  2.230337619781494 seconds elapsed
# Iter 515  :  Rows 97660-97850  :  2.2198407649993896 seconds elapsed
# Iter 516  :  Rows 97850-98040  :  2.2102460861206055 seconds elapsed
# Iter 517  :  Rows 98040-98230  :  2.2287940979003906 seconds elapsed
# Iter 518  :  Rows 98230-98420  :  2.2120721340179443 seconds elapsed
# Iter 519  :  Rows 98420-98610  :  2.200990915298462 seconds elapsed
# Iter 520  :  Rows 98610-98800  :  2.221276044845581 seconds elapsed
# Iter 521  :  Rows 98800-98990  :  2.232883930206299 seconds elapsed
# Iter 522  :  Rows 98990-99180  :  2.2097861766815186 seconds elapsed
# Iter 523  :  Rows 99180-99370  :  2.235921859741211 seconds elapsed
# Iter 524  :  Rows 99370-99560  :  2.210348129272461 seconds elapsed
# Iter 525  :  Rows 99560-99750  :  2.2412538528442383 seconds elapsed
# Iter 526  :  Rows 99750-99940  :  2.2122459411621094 seconds elapsed
# Iter 527  :  Rows 99940-100130  :  2.1998422145843506 seconds elapsed
# Iter 528  :  Rows 100130-100320  :  2.2191731929779053 seconds elapsed
# Iter 529  :  Rows 100320-100510  :  2.2099671363830566 seconds elapsed
# Iter 530  :  Rows 100510-100700  :  2.22196102142334 seconds elapsed
# Iter 531  :  Rows 100700-100890  :  2.2194602489471436 seconds elapsed
# Iter 532  :  Rows 100890-101080  :  2.217794179916382 seconds elapsed
# Iter 533  :  Rows 101080-101270  :  2.215782880783081 seconds elapsed
# Iter 534  :  Rows 101270-101460  :  2.244511842727661 seconds elapsed
# Iter 535  :  Rows 101460-101650  :  2.2226691246032715 seconds elapsed
# Iter 536  :  Rows 101650-101840  :  2.2274558544158936 seconds elapsed
# Iter 537  :  Rows 101840-102030  :  2.2172701358795166 seconds elapsed
# Iter 538  :  Rows 102030-102220  :  2.2064666748046875 seconds elapsed
# Iter 539  :  Rows 102220-102410  :  2.2194020748138428 seconds elapsed
# Iter 540  :  Rows 102410-102600  :  2.234938859939575 seconds elapsed
# Iter 541  :  Rows 102600-102790  :  2.2250492572784424 seconds elapsed
# Iter 542  :  Rows 102790-102980  :  2.214745283126831 seconds elapsed
# Iter 543  :  Rows 102980-103170  :  2.223341941833496 seconds elapsed
# Iter 544  :  Rows 103170-103360  :  2.239948034286499 seconds elapsed
# Iter 545  :  Rows 103360-103550  :  2.216583013534546 seconds elapsed
# Iter 546  :  Rows 103550-103740  :  2.2079391479492188 seconds elapsed
# Iter 547  :  Rows 103740-103930  :  2.2157537937164307 seconds elapsed
# Iter 548  :  Rows 103930-104120  :  2.221871852874756 seconds elapsed
# Iter 549  :  Rows 104120-104310  :  2.205996036529541 seconds elapsed
# Iter 550  :  Rows 104310-104500  :  2.2217648029327393 seconds elapsed
# Iter 551  :  Rows 104500-104690  :  2.2135329246520996 seconds elapsed
# Iter 552  :  Rows 104690-104880  :  2.243933916091919 seconds elapsed
# Iter 553  :  Rows 104880-105070  :  2.20046067237854 seconds elapsed
# Iter 554  :  Rows 105070-105260  :  2.236541986465454 seconds elapsed
# Iter 555  :  Rows 105260-105450  :  2.223222017288208 seconds elapsed
# Iter 556  :  Rows 105450-105640  :  2.20416259765625 seconds elapsed
# Iter 557  :  Rows 105640-105830  :  2.231121778488159 seconds elapsed
# Iter 558  :  Rows 105830-106020  :  2.2303810119628906 seconds elapsed
# Iter 559  :  Rows 106020-106210  :  2.2204020023345947 seconds elapsed
# Iter 560  :  Rows 106210-106400  :  2.223529100418091 seconds elapsed
# Iter 561  :  Rows 106400-106590  :  2.2188169956207275 seconds elapsed
# Iter 562  :  Rows 106590-106780  :  2.224853992462158 seconds elapsed
# Iter 563  :  Rows 106780-106970  :  2.221405267715454 seconds elapsed
# Iter 564  :  Rows 106970-107160  :  2.2190849781036377 seconds elapsed
# Iter 565  :  Rows 107160-107350  :  2.200500965118408 seconds elapsed
# Iter 566  :  Rows 107350-107540  :  2.2278761863708496 seconds elapsed
# Iter 567  :  Rows 107540-107730  :  2.244971990585327 seconds elapsed
# Iter 568  :  Rows 107730-107920  :  2.2053210735321045 seconds elapsed
# Iter 569  :  Rows 107920-108110  :  2.202360153198242 seconds elapsed
# Iter 570  :  Rows 108110-108300  :  2.2149410247802734 seconds elapsed
# Iter 571  :  Rows 108300-108490  :  2.2256548404693604 seconds elapsed
# Iter 572  :  Rows 108490-108680  :  2.2135369777679443 seconds elapsed
# Iter 573  :  Rows 108680-108870  :  2.2134158611297607 seconds elapsed
# Iter 574  :  Rows 108870-109060  :  2.241502046585083 seconds elapsed
# Iter 575  :  Rows 109060-109250  :  2.251589298248291 seconds elapsed
# Iter 576  :  Rows 109250-109440  :  2.2320587635040283 seconds elapsed
# Iter 577  :  Rows 109440-109630  :  2.224714994430542 seconds elapsed
# Iter 578  :  Rows 109630-109820  :  2.2548868656158447 seconds elapsed
# Iter 579  :  Rows 109820-110010  :  2.227139949798584 seconds elapsed
# Iter 580  :  Rows 110010-110200  :  2.2083163261413574 seconds elapsed
# Iter 581  :  Rows 110200-110390  :  2.250154972076416 seconds elapsed
# Iter 582  :  Rows 110390-110580  :  2.2355520725250244 seconds elapsed
# Iter 583  :  Rows 110580-110770  :  2.230937957763672 seconds elapsed
# Iter 584  :  Rows 110770-110960  :  2.228123188018799 seconds elapsed
# Iter 585  :  Rows 110960-111150  :  2.2223150730133057 seconds elapsed
# Iter 586  :  Rows 111150-111340  :  2.221215009689331 seconds elapsed
# Iter 587  :  Rows 111340-111530  :  2.217158317565918 seconds elapsed
# Iter 588  :  Rows 111530-111720  :  2.2450122833251953 seconds elapsed
# Iter 589  :  Rows 111720-111910  :  2.2204020023345947 seconds elapsed
# Iter 590  :  Rows 111910-112100  :  2.23659610748291 seconds elapsed
# Iter 591  :  Rows 112100-112290  :  2.2281129360198975 seconds elapsed
# Iter 592  :  Rows 112290-112480  :  2.207677125930786 seconds elapsed
# Iter 593  :  Rows 112480-112670  :  2.24101185798645 seconds elapsed
# Iter 594  :  Rows 112670-112860  :  2.232294797897339 seconds elapsed
# Iter 595  :  Rows 112860-113050  :  2.250706911087036 seconds elapsed
# Iter 596  :  Rows 113050-113240  :  2.2198870182037354 seconds elapsed
# Iter 597  :  Rows 113240-113430  :  2.2278480529785156 seconds elapsed
# Iter 598  :  Rows 113430-113620  :  2.2395410537719727 seconds elapsed
# Iter 599  :  Rows 113620-113810  :  2.2315359115600586 seconds elapsed
# Iter 600  :  Rows 113810-114000  :  2.222078800201416 seconds elapsed
# Iter 601  :  Rows 114000-114190  :  2.208866834640503 seconds elapsed
# Iter 602  :  Rows 114190-114380  :  2.2343389987945557 seconds elapsed
# Iter 603  :  Rows 114380-114570  :  2.2012526988983154 seconds elapsed
# Iter 604  :  Rows 114570-114760  :  2.2260098457336426 seconds elapsed
# Iter 605  :  Rows 114760-114950  :  2.203031063079834 seconds elapsed
# Iter 606  :  Rows 114950-115140  :  2.228433847427368 seconds elapsed
# Iter 607  :  Rows 115140-115330  :  2.213196039199829 seconds elapsed
# Iter 608  :  Rows 115330-115520  :  2.217625141143799 seconds elapsed
# Iter 609  :  Rows 115520-115710  :  2.237542152404785 seconds elapsed
# Iter 610  :  Rows 115710-115900  :  2.1864922046661377 seconds elapsed
# Iter 611  :  Rows 115900-116090  :  2.2266931533813477 seconds elapsed
# Iter 612  :  Rows 116090-116280  :  2.221708059310913 seconds elapsed
# Iter 613  :  Rows 116280-116470  :  2.212054967880249 seconds elapsed
# Iter 614  :  Rows 116470-116660  :  2.2252390384674072 seconds elapsed
# Iter 615  :  Rows 116660-116850  :  2.2173640727996826 seconds elapsed
# Iter 616  :  Rows 116850-117040  :  2.2326772212982178 seconds elapsed
# Iter 617  :  Rows 117040-117230  :  2.2180023193359375 seconds elapsed
# Iter 618  :  Rows 117230-117420  :  2.254279136657715 seconds elapsed
# Iter 619  :  Rows 117420-117610  :  2.227268934249878 seconds elapsed
# Iter 620  :  Rows 117610-117800  :  2.2299299240112305 seconds elapsed
# Iter 621  :  Rows 117800-117990  :  2.2243120670318604 seconds elapsed
# Iter 622  :  Rows 117990-118180  :  2.2312159538269043 seconds elapsed
# Iter 623  :  Rows 118180-118370  :  2.22530198097229 seconds elapsed
# Iter 624  :  Rows 118370-118560  :  2.2405269145965576 seconds elapsed
# Iter 625  :  Rows 118560-118750  :  2.223357915878296 seconds elapsed
# Iter 626  :  Rows 118750-118940  :  2.215662956237793 seconds elapsed
# Iter 627  :  Rows 118940-119130  :  2.218177080154419 seconds elapsed
# Iter 628  :  Rows 119130-119320  :  2.2255148887634277 seconds elapsed
# Iter 629  :  Rows 119320-119510  :  2.2255733013153076 seconds elapsed
# Iter 630  :  Rows 119510-119700  :  2.250922203063965 seconds elapsed
# Iter 631  :  Rows 119700-119890  :  2.232297897338867 seconds elapsed
# Iter 632  :  Rows 119890-120080  :  2.2050161361694336 seconds elapsed
# Iter 633  :  Rows 120080-120270  :  2.224998950958252 seconds elapsed
# Iter 634  :  Rows 120270-120460  :  2.2265279293060303 seconds elapsed
# Iter 635  :  Rows 120460-120650  :  2.2387938499450684 seconds elapsed
# Iter 636  :  Rows 120650-120840  :  2.227574110031128 seconds elapsed
# Iter 637  :  Rows 120840-121030  :  2.217291831970215 seconds elapsed
# Iter 638  :  Rows 121030-121220  :  2.220513105392456 seconds elapsed
# Iter 639  :  Rows 121220-121410  :  2.2205710411071777 seconds elapsed
# Iter 640  :  Rows 121410-121600  :  2.2253799438476562 seconds elapsed
# Iter 641  :  Rows 121600-121790  :  2.2230420112609863 seconds elapsed
# Iter 642  :  Rows 121790-121980  :  2.206523895263672 seconds elapsed
# Iter 643  :  Rows 121980-122170  :  2.203731060028076 seconds elapsed
# Iter 644  :  Rows 122170-122360  :  2.250577926635742 seconds elapsed
# Iter 645  :  Rows 122360-122550  :  2.2381021976470947 seconds elapsed
# Iter 646  :  Rows 122550-122740  :  2.2373392581939697 seconds elapsed
# Iter 647  :  Rows 122740-122930  :  2.2184650897979736 seconds elapsed
# Iter 648  :  Rows 122930-123120  :  2.226628065109253 seconds elapsed
# Iter 649  :  Rows 123120-123310  :  2.239366054534912 seconds elapsed
# Iter 650  :  Rows 123310-123500  :  2.23909592628479 seconds elapsed
# Iter 651  :  Rows 123500-123690  :  2.2227320671081543 seconds elapsed
# Iter 652  :  Rows 123690-123880  :  2.2285420894622803 seconds elapsed
# Iter 653  :  Rows 123880-124070  :  2.194500207901001 seconds elapsed
# Iter 654  :  Rows 124070-124260  :  2.232253074645996 seconds elapsed
# Iter 655  :  Rows 124260-124450  :  2.223796844482422 seconds elapsed
# Iter 656  :  Rows 124450-124640  :  2.229099988937378 seconds elapsed
# Iter 657  :  Rows 124640-124830  :  2.2412569522857666 seconds elapsed
# Iter 658  :  Rows 124830-125020  :  2.235440969467163 seconds elapsed
# Iter 659  :  Rows 125020-125210  :  2.2289488315582275 seconds elapsed
# Iter 660  :  Rows 125210-125400  :  2.202124834060669 seconds elapsed
# Iter 661  :  Rows 125400-125590  :  2.240345001220703 seconds elapsed
# Iter 662  :  Rows 125590-125780  :  2.218071937561035 seconds elapsed
# Iter 663  :  Rows 125780-125970  :  2.2163100242614746 seconds elapsed
# Iter 664  :  Rows 125970-126160  :  2.221165180206299 seconds elapsed
# Iter 665  :  Rows 126160-126350  :  2.2206029891967773 seconds elapsed
# Iter 666  :  Rows 126350-126540  :  2.224148988723755 seconds elapsed
# Iter 667  :  Rows 126540-126730  :  2.243846893310547 seconds elapsed
# Iter 668  :  Rows 126730-126920  :  2.2270736694335938 seconds elapsed
# Iter 669  :  Rows 126920-127110  :  2.247934103012085 seconds elapsed
# Iter 670  :  Rows 127110-127300  :  2.2258291244506836 seconds elapsed
# Iter 671  :  Rows 127300-127490  :  2.2331249713897705 seconds elapsed
# Iter 672  :  Rows 127490-127680  :  2.2311220169067383 seconds elapsed
# Iter 673  :  Rows 127680-127870  :  2.1955809593200684 seconds elapsed
# Iter 674  :  Rows 127870-128060  :  2.204909086227417 seconds elapsed
# Iter 675  :  Rows 128060-128250  :  2.239901065826416 seconds elapsed
# Iter 676  :  Rows 128250-128440  :  2.23081111907959 seconds elapsed
# Iter 677  :  Rows 128440-128630  :  2.231311082839966 seconds elapsed
# Iter 678  :  Rows 128630-128820  :  2.214027166366577 seconds elapsed
# Iter 679  :  Rows 128820-129010  :  2.2286899089813232 seconds elapsed
# Iter 680  :  Rows 129010-129200  :  2.199998140335083 seconds elapsed
# Iter 681  :  Rows 129200-129390  :  2.2362148761749268 seconds elapsed
# Iter 682  :  Rows 129390-129580  :  2.227552890777588 seconds elapsed
# Iter 683  :  Rows 129580-129770  :  2.2226269245147705 seconds elapsed
# Iter 684  :  Rows 129770-129960  :  2.23779296875 seconds elapsed
# Iter 685  :  Rows 129960-130150  :  2.2297070026397705 seconds elapsed
# Iter 686  :  Rows 130150-130340  :  2.2212350368499756 seconds elapsed
# Iter 687  :  Rows 130340-130530  :  2.2192680835723877 seconds elapsed
# Iter 688  :  Rows 130530-130720  :  2.1996421813964844 seconds elapsed
# Iter 689  :  Rows 130720-130910  :  2.227609157562256 seconds elapsed
# Iter 690  :  Rows 130910-131100  :  2.249843120574951 seconds elapsed
# Iter 691  :  Rows 131100-131290  :  2.242672920227051 seconds elapsed
# Iter 692  :  Rows 131290-131480  :  2.2181341648101807 seconds elapsed
# Iter 693  :  Rows 131480-131670  :  2.2179179191589355 seconds elapsed
# Iter 694  :  Rows 131670-131860  :  2.2375648021698 seconds elapsed
# Iter 695  :  Rows 131860-132050  :  2.2213523387908936 seconds elapsed
# Iter 696  :  Rows 132050-132240  :  2.228818893432617 seconds elapsed
# Iter 697  :  Rows 132240-132430  :  2.216240882873535 seconds elapsed
# Iter 698  :  Rows 132430-132620  :  2.2133941650390625 seconds elapsed
# Iter 699  :  Rows 132620-132810  :  2.2508647441864014 seconds elapsed
# ...
# Iter 3482  :  Rows 661390-661580  :  2.20147705078125 seconds elapsed
# Iter 3483  :  Rows 661580-661770  :  2.2074482440948486 seconds elapsed
# Iter 3484  :  Rows 661770-661960  :  2.227602958679199 seconds elapsed
# Iter 3485  :  Rows 661960-662150  :  2.369614839553833 seconds elapsed
# Iter 3486  :  Rows 662150-662340  :  2.2668330669403076 seconds elapsed
# Iter 3487  :  Rows 662340-662530  :  2.200220823287964 seconds elapsed
# Iter 3488  :  Rows 662530-662720  :  2.220158100128174 seconds elapsed
# Iter 3489  :  Rows 662720-662910  :  2.2051148414611816 seconds elapsed
# Iter 3490  :  Rows 662910-663100  :  2.1809821128845215 seconds elapsed
# Iter 3491  :  Rows 663100-663290  :  2.18871808052063 seconds elapsed
# Iter 3492  :  Rows 663290-663480  :  2.1904211044311523 seconds elapsed
# Iter 3493  :  Rows 663480-663670  :  2.186706066131592 seconds elapsed
# Iter 3494  :  Rows 663670-663860  :  2.1840600967407227 seconds elapsed
# Iter 3495  :  Rows 663860-664050  :  2.2012507915496826 seconds elapsed
# Iter 3496  :  Rows 664050-664240  :  2.216677188873291 seconds elapsed
# Iter 3497  :  Rows 664240-664430  :  2.2183148860931396 seconds elapsed
# Iter 3498  :  Rows 664430-664620  :  2.193476915359497 seconds elapsed
# Iter 3499  :  Rows 664620-664810  :  2.1960971355438232 seconds elapsed
# Iter 3500  :  Rows 664810-665000  :  2.2064201831817627 seconds elapsed
# Iter 3501  :  Rows 665000-665190  :  2.2191247940063477 seconds elapsed
# Iter 3502  :  Rows 665190-665380  :  2.1975700855255127 seconds elapsed
# Iter 3503  :  Rows 665380-665570  :  2.1934962272644043 seconds elapsed
# Iter 3504  :  Rows 665570-665760  :  2.2070491313934326 seconds elapsed
# Iter 3505  :  Rows 665760-665950  :  2.1998541355133057 seconds elapsed
# Iter 3506  :  Rows 665950-666140  :  2.189790964126587 seconds elapsed
# Iter 3507  :  Rows 666140-666330  :  2.179725170135498 seconds elapsed
# Iter 3508  :  Rows 666330-666520  :  2.198262929916382 seconds elapsed
# Iter 3509  :  Rows 666520-666710  :  2.218183755874634 seconds elapsed
# Iter 3510  :  Rows 666710-666900  :  2.228863000869751 seconds elapsed
# Iter 3511  :  Rows 666900-667090  :  2.1844189167022705 seconds elapsed
# Iter 3512  :  Rows 667090-667280  :  2.2050371170043945 seconds elapsed
# Iter 3513  :  Rows 667280-667470  :  2.216999053955078 seconds elapsed
# Iter 3514  :  Rows 667470-667660  :  2.229124069213867 seconds elapsed
# Iter 3515  :  Rows 667660-667850  :  2.2290380001068115 seconds elapsed
# Iter 3516  :  Rows 667850-668040  :  2.1969258785247803 seconds elapsed
# Iter 3517  :  Rows 668040-668230  :  2.1827609539031982 seconds elapsed
# Iter 3518  :  Rows 668230-668420  :  2.1940979957580566 seconds elapsed
# Iter 3519  :  Rows 668420-668610  :  2.190275192260742 seconds elapsed
# Iter 3520  :  Rows 668610-668800  :  2.1923601627349854 seconds elapsed
# Iter 3521  :  Rows 668800-668990  :  2.2139132022857666 seconds elapsed
# Iter 3522  :  Rows 668990-669180  :  2.1863150596618652 seconds elapsed
# Iter 3523  :  Rows 669180-669370  :  2.218745231628418 seconds elapsed
# Iter 3524  :  Rows 669370-669560  :  2.1831510066986084 seconds elapsed
# Iter 3525  :  Rows 669560-669750  :  2.200716018676758 seconds elapsed
# Iter 3526  :  Rows 669750-669940  :  2.1945600509643555 seconds elapsed
# Iter 3527  :  Rows 669940-670130  :  2.2368381023406982 seconds elapsed
# Iter 3528  :  Rows 670130-670320  :  2.195488929748535 seconds elapsed
# Iter 3529  :  Rows 670320-670510  :  2.1855099201202393 seconds elapsed
# Iter 3530  :  Rows 670510-670700  :  2.1919682025909424 seconds elapsed
# Iter 3531  :  Rows 670700-670890  :  2.196578025817871 seconds elapsed
# Iter 3532  :  Rows 670890-671080  :  2.2303528785705566 seconds elapsed
# Iter 3533  :  Rows 671080-671270  :  2.221623182296753 seconds elapsed
# Iter 3534  :  Rows 671270-671460  :  2.228599786758423 seconds elapsed
# Iter 3535  :  Rows 671460-671650  :  2.2250518798828125 seconds elapsed
# Iter 3536  :  Rows 671650-671840  :  2.2423601150512695 seconds elapsed
# Iter 3537  :  Rows 671840-672030  :  2.214967966079712 seconds elapsed
# Iter 3538  :  Rows 672030-672220  :  2.2069151401519775 seconds elapsed
# Iter 3539  :  Rows 672220-672410  :  2.210850954055786 seconds elapsed
# Iter 3540  :  Rows 672410-672600  :  2.221461057662964 seconds elapsed
# Iter 3541  :  Rows 672600-672790  :  2.2331039905548096 seconds elapsed
# Iter 3542  :  Rows 672790-672980  :  2.213754177093506 seconds elapsed
# Iter 3543  :  Rows 672980-673170  :  2.2150962352752686 seconds elapsed
# Iter 3544  :  Rows 673170-673360  :  2.219701051712036 seconds elapsed
# Iter 3545  :  Rows 673360-673550  :  2.2218921184539795 seconds elapsed
# Iter 3546  :  Rows 673550-673740  :  2.2045609951019287 seconds elapsed
# Iter 3547  :  Rows 673740-673930  :  2.222764015197754 seconds elapsed
# Iter 3548  :  Rows 673930-674120  :  2.2245900630950928 seconds elapsed
# Iter 3549  :  Rows 674120-674310  :  2.219252109527588 seconds elapsed
# Iter 3550  :  Rows 674310-674500  :  2.180989980697632 seconds elapsed
# Iter 3551  :  Rows 674500-674690  :  2.2271339893341064 seconds elapsed
# Iter 3552  :  Rows 674690-674880  :  2.232923984527588 seconds elapsed
# Iter 3553  :  Rows 674880-675070  :  2.17533802986145 seconds elapsed
# Iter 3554  :  Rows 675070-675260  :  2.2471020221710205 seconds elapsed
# Iter 3555  :  Rows 675260-675450  :  2.2306790351867676 seconds elapsed
# Iter 3556  :  Rows 675450-675640  :  2.2095019817352295 seconds elapsed
# Iter 3557  :  Rows 675640-675830  :  2.214015007019043 seconds elapsed
# Iter 3558  :  Rows 675830-676020  :  2.23419189453125 seconds elapsed
# Iter 3559  :  Rows 676020-676210  :  2.215855121612549 seconds elapsed
# Iter 3560  :  Rows 676210-676400  :  2.213373899459839 seconds elapsed
# Iter 3561  :  Rows 676400-676590  :  2.206146001815796 seconds elapsed
# Iter 3562  :  Rows 676590-676780  :  2.2006499767303467 seconds elapsed
# Iter 3563  :  Rows 676780-676970  :  2.2256100177764893 seconds elapsed
# Iter 3564  :  Rows 676970-677160  :  2.225853204727173 seconds elapsed
# Iter 3565  :  Rows 677160-677350  :  2.234639883041382 seconds elapsed
# Iter 3566  :  Rows 677350-677540  :  2.226951837539673 seconds elapsed
# Iter 3567  :  Rows 677540-677730  :  2.2100391387939453 seconds elapsed
# Iter 3568  :  Rows 677730-677920  :  2.226590156555176 seconds elapsed
# Iter 3569  :  Rows 677920-678110  :  2.212054967880249 seconds elapsed
# Iter 3570  :  Rows 678110-678300  :  2.2364931106567383 seconds elapsed
# Iter 3571  :  Rows 678300-678490  :  2.2377803325653076 seconds elapsed
# Iter 3572  :  Rows 678490-678680  :  2.2080230712890625 seconds elapsed
# Iter 3573  :  Rows 678680-678870  :  2.2293522357940674 seconds elapsed
# Iter 3574  :  Rows 678870-679060  :  2.230329751968384 seconds elapsed
# Iter 3575  :  Rows 679060-679250  :  2.2250592708587646 seconds elapsed
# Iter 3576  :  Rows 679250-679440  :  2.2230701446533203 seconds elapsed
# Iter 3577  :  Rows 679440-679630  :  2.228133201599121 seconds elapsed
# Iter 3578  :  Rows 679630-679820  :  2.227325916290283 seconds elapsed
# Iter 3579  :  Rows 679820-680010  :  2.214284896850586 seconds elapsed
# Iter 3580  :  Rows 680010-680200  :  2.207711935043335 seconds elapsed
# Iter 3581  :  Rows 680200-680390  :  2.2130019664764404 seconds elapsed
# Iter 3582  :  Rows 680390-680580  :  2.213888645172119 seconds elapsed
# Iter 3583  :  Rows 680580-680770  :  2.1992361545562744 seconds elapsed
# Iter 3584  :  Rows 680770-680960  :  2.2361631393432617 seconds elapsed
# Iter 3585  :  Rows 680960-681150  :  2.230241060256958 seconds elapsed
# Iter 3586  :  Rows 681150-681340  :  2.227130889892578 seconds elapsed
# Iter 3587  :  Rows 681340-681530  :  2.2103137969970703 seconds elapsed
# Iter 3588  :  Rows 681530-681720  :  2.2009809017181396 seconds elapsed
# Iter 3589  :  Rows 681720-681910  :  2.231416702270508 seconds elapsed
# Iter 3590  :  Rows 681910-682100  :  2.176589250564575 seconds elapsed
# Iter 3591  :  Rows 682100-682290  :  2.250457763671875 seconds elapsed
# Iter 3592  :  Rows 682290-682480  :  2.205331802368164 seconds elapsed
# Iter 3593  :  Rows 682480-682670  :  2.2170839309692383 seconds elapsed
# Iter 3594  :  Rows 682670-682860  :  2.2333786487579346 seconds elapsed
# Iter 3595  :  Rows 682860-683050  :  2.221299886703491 seconds elapsed
# Iter 3596  :  Rows 683050-683240  :  2.2119431495666504 seconds elapsed
# Iter 3597  :  Rows 683240-683430  :  2.236949920654297 seconds elapsed
# Iter 3598  :  Rows 683430-683620  :  2.2427918910980225 seconds elapsed
# Iter 3599  :  Rows 683620-683810  :  2.218035936355591 seconds elapsed
# Iter 3600  :  Rows 683810-684000  :  2.214689254760742 seconds elapsed
# Iter 3601  :  Rows 684000-684190  :  2.2127299308776855 seconds elapsed
# Iter 3602  :  Rows 684190-684380  :  2.21683406829834 seconds elapsed
# Iter 3603  :  Rows 684380-684570  :  2.2432961463928223 seconds elapsed
# Iter 3604  :  Rows 684570-684760  :  2.216130256652832 seconds elapsed
# Iter 3605  :  Rows 684760-684950  :  2.225377082824707 seconds elapsed
# Iter 3606  :  Rows 684950-685140  :  2.2185637950897217 seconds elapsed
# Iter 3607  :  Rows 685140-685330  :  2.226839065551758 seconds elapsed
# Iter 3608  :  Rows 685330-685520  :  2.2242050170898438 seconds elapsed
# Iter 3609  :  Rows 685520-685710  :  2.226043939590454 seconds elapsed
# Iter 3610  :  Rows 685710-685900  :  2.2092480659484863 seconds elapsed
# Iter 3611  :  Rows 685900-686090  :  2.228442907333374 seconds elapsed
# Iter 3612  :  Rows 686090-686280  :  2.2139830589294434 seconds elapsed
# Iter 3613  :  Rows 686280-686470  :  2.2144219875335693 seconds elapsed
# Iter 3614  :  Rows 686470-686660  :  2.201709032058716 seconds elapsed
# Iter 3615  :  Rows 686660-686850  :  2.2161920070648193 seconds elapsed
# Iter 3616  :  Rows 686850-687040  :  2.209606885910034 seconds elapsed
# Iter 3617  :  Rows 687040-687230  :  2.20135498046875 seconds elapsed
# Iter 3618  :  Rows 687230-687420  :  2.220447063446045 seconds elapsed
# Iter 3619  :  Rows 687420-687610  :  2.216339111328125 seconds elapsed
# Iter 3620  :  Rows 687610-687800  :  2.239396810531616 seconds elapsed
# Iter 3621  :  Rows 687800-687990  :  2.243518114089966 seconds elapsed
# Iter 3622  :  Rows 687990-688180  :  2.247831106185913 seconds elapsed
# Iter 3623  :  Rows 688180-688370  :  2.229311943054199 seconds elapsed
# Iter 3624  :  Rows 688370-688560  :  2.243011951446533 seconds elapsed
# Iter 3625  :  Rows 688560-688750  :  2.233905076980591 seconds elapsed
# Iter 3626  :  Rows 688750-688940  :  2.202270746231079 seconds elapsed
# Iter 3627  :  Rows 688940-689130  :  2.2286770343780518 seconds elapsed
# Iter 3628  :  Rows 689130-689320  :  2.2125039100646973 seconds elapsed
# Iter 3629  :  Rows 689320-689510  :  2.2555110454559326 seconds elapsed
# Iter 3630  :  Rows 689510-689700  :  2.2155301570892334 seconds elapsed
# Iter 3631  :  Rows 689700-689890  :  2.198996067047119 seconds elapsed
# Iter 3632  :  Rows 689890-690080  :  2.214862108230591 seconds elapsed
# Iter 3633  :  Rows 690080-690270  :  2.2232940196990967 seconds elapsed
# Iter 3634  :  Rows 690270-690460  :  2.203645944595337 seconds elapsed
# Iter 3635  :  Rows 690460-690650  :  2.2260890007019043 seconds elapsed
# Iter 3636  :  Rows 690650-690840  :  2.220216989517212 seconds elapsed
# Iter 3637  :  Rows 690840-691030  :  2.2124547958374023 seconds elapsed
# Iter 3638  :  Rows 691030-691220  :  2.233678102493286 seconds elapsed
# Iter 3639  :  Rows 691220-691410  :  2.289348840713501 seconds elapsed
# Iter 3640  :  Rows 691410-691600  :  2.231369972229004 seconds elapsed
# Iter 3641  :  Rows 691600-691790  :  2.242119789123535 seconds elapsed
# Iter 3642  :  Rows 691790-691980  :  2.216269016265869 seconds elapsed
# Iter 3643  :  Rows 691980-692170  :  2.2103638648986816 seconds elapsed
# Iter 3644  :  Rows 692170-692360  :  2.225162982940674 seconds elapsed
# Iter 3645  :  Rows 692360-692550  :  2.21073579788208 seconds elapsed
# Iter 3646  :  Rows 692550-692740  :  2.2201850414276123 seconds elapsed
# Iter 3647  :  Rows 692740-692930  :  2.313019037246704 seconds elapsed
# Iter 3648  :  Rows 692930-693120  :  2.2253000736236572 seconds elapsed
# Iter 3649  :  Rows 693120-693310  :  2.23712420463562 seconds elapsed
# Iter 3650  :  Rows 693310-693500  :  2.2365081310272217 seconds elapsed
# Iter 3651  :  Rows 693500-693690  :  2.229808807373047 seconds elapsed
# Iter 3652  :  Rows 693690-693880  :  2.2280850410461426 seconds elapsed
# Iter 3653  :  Rows 693880-694070  :  2.216454267501831 seconds elapsed
# Iter 3654  :  Rows 694070-694260  :  2.2164790630340576 seconds elapsed
# Iter 3655  :  Rows 694260-694450  :  2.227200984954834 seconds elapsed
# Iter 3656  :  Rows 694450-694640  :  2.231045961380005 seconds elapsed
# Iter 3657  :  Rows 694640-694830  :  2.2250959873199463 seconds elapsed
# Iter 3658  :  Rows 694830-695020  :  2.24826717376709 seconds elapsed
# Iter 3659  :  Rows 695020-695210  :  2.2508389949798584 seconds elapsed
# Iter 3660  :  Rows 695210-695400  :  2.2507688999176025 seconds elapsed
# Iter 3661  :  Rows 695400-695590  :  2.205904245376587 seconds elapsed
# Iter 3662  :  Rows 695590-695780  :  2.2737479209899902 seconds elapsed
# Iter 3663  :  Rows 695780-695970  :  2.218966007232666 seconds elapsed
# Iter 3664  :  Rows 695970-696160  :  2.220146894454956 seconds elapsed
# Iter 3665  :  Rows 696160-696350  :  2.2314860820770264 seconds elapsed
# Iter 3666  :  Rows 696350-696540  :  2.209144115447998 seconds elapsed
# Iter 3667  :  Rows 696540-696730  :  2.215909004211426 seconds elapsed
# Iter 3668  :  Rows 696730-696920  :  2.2313809394836426 seconds elapsed
# Iter 3669  :  Rows 696920-697110  :  2.2129290103912354 seconds elapsed
# Iter 3670  :  Rows 697110-697300  :  2.2070279121398926 seconds elapsed
# Iter 3671  :  Rows 697300-697490  :  2.216949939727783 seconds elapsed
# Iter 3672  :  Rows 697490-697680  :  2.200483798980713 seconds elapsed
# Iter 3673  :  Rows 697680-697870  :  2.1997838020324707 seconds elapsed
# Iter 3674  :  Rows 697870-698060  :  2.229172945022583 seconds elapsed
# Iter 3675  :  Rows 698060-698250  :  2.2352850437164307 seconds elapsed
# Iter 3676  :  Rows 698250-698440  :  2.2018418312072754 seconds elapsed
# Iter 3677  :  Rows 698440-698630  :  2.204404354095459 seconds elapsed
# Iter 3678  :  Rows 698630-698820  :  2.236440896987915 seconds elapsed
# Iter 3679  :  Rows 698820-699010  :  2.211606979370117 seconds elapsed
# Iter 3680  :  Rows 699010-699200  :  2.2284951210021973 seconds elapsed
# Iter 3681  :  Rows 699200-699390  :  2.211934804916382 seconds elapsed
# Iter 3682  :  Rows 699390-699580  :  2.2137420177459717 seconds elapsed
# Iter 3683  :  Rows 699580-699770  :  2.2276201248168945 seconds elapsed
# Iter 3684  :  Rows 699770-699960  :  2.2115111351013184 seconds elapsed
# Iter 3685  :  Rows 699960-700150  :  2.2317886352539062 seconds elapsed
# Iter 3686  :  Rows 700150-700340  :  2.212171792984009 seconds elapsed
# Iter 3687  :  Rows 700340-700530  :  2.211855888366699 seconds elapsed
# Iter 3688  :  Rows 700530-700720  :  2.2073264122009277 seconds elapsed
# Iter 3689  :  Rows 700720-700910  :  2.2201452255249023 seconds elapsed
# Iter 3690  :  Rows 700910-701100  :  2.2402608394622803 seconds elapsed
# Iter 3691  :  Rows 701100-701290  :  2.2436318397521973 seconds elapsed
# Iter 3692  :  Rows 701290-701480  :  2.1966331005096436 seconds elapsed
# Iter 3693  :  Rows 701480-701670  :  2.2163829803466797 seconds elapsed
# Iter 3694  :  Rows 701670-701860  :  2.2321228981018066 seconds elapsed
# Iter 3695  :  Rows 701860-702050  :  2.2113730907440186 seconds elapsed
# Iter 3696  :  Rows 702050-702240  :  2.215188980102539 seconds elapsed
# Iter 3697  :  Rows 702240-702430  :  2.22426176071167 seconds elapsed
# Iter 3698  :  Rows 702430-702620  :  2.21742582321167 seconds elapsed
# Iter 3699  :  Rows 702620-702810  :  2.2201321125030518 seconds elapsed
# Iter 3700  :  Rows 702810-703000  :  2.2162089347839355 seconds elapsed
# Iter 3701  :  Rows 703000-703190  :  2.222493886947632 seconds elapsed
# Iter 3702  :  Rows 703190-703380  :  2.2055652141571045 seconds elapsed
# Iter 3703  :  Rows 703380-703532  :  2.0169143676757812 seconds elapsed
# CPU times: user 8h 40min 54s, sys: 1h 15min 24s, total: 9h 56min 18s
# Wall time: 2h 16min 41s

# %%
del cc_array

# %%
cc_wed = list(chain.from_iterable(cc_wed_chunked))
print(len(cc_wed))
# Out:
# 703532

# %%
print(f"""Max WED: {max(cc_wed)}
Min WED: {min(cc_wed)}
Mean: {np.mean(cc_wed)}
Std Dev: {np.std(cc_wed)}""")
# Out:
# Max WED: 0.8484386464904401
# Min WED: 0.1815071659402093
# Mean: 0.27598083037616433
# Std Dev: 0.05075569724079787

# %%
wed_indexed = list(enumerate(cc_wed))
wed_indexed10k = sorted(wed_indexed, key=itemgetter(1))[-10000:]
wed_indices10k = [tup[0] for tup in wed_indexed10k]
wed_scores10k = [tup[1] for tup in wed_indexed10k]

# %%
print(f"""Max WED in subsample: {max(wed_scores10k)}
Min WED: {min(wed_scores10k)}
Mean: {np.mean(wed_scores10k)}
Std Dev: {np.std(wed_scores10k)}""")
# Out:
# Max WED in subsample: 0.8484386464904401
# Min WED: 0.4253332667618559
# Mean: 0.4456780084688563
# Std Dev: 0.028223730462232817

# %%
with open(os.path.join("data","cc_news.json"), "r") as infile:
    cc_news = json.load(infile)

print(len(cc_news))
# Out:
# 703532

# %%
# %%time

cc_wed10k = [
    article for idx, article in enumerate(cc_news) if idx in wed_indices10k
]
# Out:
# CPU times: user 48.2 s, sys: 147 ms, total: 48.4 s
# Wall time: 48.4 s

# %%
with open(os.path.join("data", "cc_wed10k.json"), "w") as outfile:
    json.dump(cc_wed10k, outfile)

# %%
with open(os.path.join("data", "cc_wed10k.txt"), "w") as outfile:
    for article in cc_wed10k:
        outfile.write(article)
